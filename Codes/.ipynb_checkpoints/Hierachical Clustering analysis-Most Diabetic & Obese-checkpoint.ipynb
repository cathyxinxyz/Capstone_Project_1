# %% [markdown]
# Clustering analysis

# %%
import seaborn as sns; sns.set(color_codes=True)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/combined.csv'
df=pd.read_csv(url,index_col='FIPS',encoding="ISO-8859-1")

# %%
#read in variable information and build variable information dictionary with variable names as key
url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/Food_atlas/Var_name_info.csv'
var_info_df=pd.read_csv(url,encoding="ISO-8859-1", index_col='var_name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3138 entries, 1001 to 56045
# Data columns (total 57 columns):
# var68                                3134 non-null float64
# var44                                3137 non-null float64
# var60                                3138 non-null float64
# var14                                3138 non-null float64
# var13                                3119 non-null float64
# var39                                3138 non-null float64
# var9                                 3119 non-null float64
# var67                                3134 non-null float64
# var3                                 3135 non-null float64
# var40                                3138 non-null float64
# var23                                3138 non-null float64
# var8                                 3119 non-null float64
# var18                                3136 non-null float64
# var2                                 3118 non-null float64
# var65                                3138 non-null float64
# var29                                2840 non-null float64
# var30                                3138 non-null float64
# var15                                3138 non-null float64
# var61                                3138 non-null float64
# var64                                3138 non-null float64
# var24                                3138 non-null float64
# var59                                3138 non-null float64
# var5                                 3119 non-null float64
# var27                                3138 non-null float64
# var6                                 3119 non-null float64
# var16                                3138 non-null float64
# var17                                3138 non-null float64
# var10                                3119 non-null float64
# var35                                3138 non-null float64
# var69                                3134 non-null float64
# var34                                3138 non-null float64
# var21                                3138 non-null float64
# var38                                3138 non-null float64
# var19                                3138 non-null float64
# var22                                3138 non-null float64
# var33                                3138 non-null float64
# var11                                3119 non-null float64
# var62                                3138 non-null float64
# var63                                3138 non-null float64
# var1                                 3091 non-null float64
# var58                                3138 non-null float64
# var36                                3138 non-null float64
# var31                                3138 non-null float64
# var28                                2840 non-null float64
# var20                                3138 non-null float64
# var32                                3138 non-null float64
# var66                                3138 non-null float64
# var12                                3119 non-null float64
# var4                                 3118 non-null float64
# var41                                3074 non-null float64
# var37                                3138 non-null float64
# var7                                 3119 non-null float64
# prevalence of diabetes               3137 non-null float64
# prevalence of obesity                3137 non-null float64
# prevalence of physical inactivity    3137 non-null float64
# frac_uninsured                       3135 non-null float64
# RUCC_2013                            3138 non-null int64
# dtypes: float64(56), int64(1)
# memory usage: 1.4 MB

# %%
from sklearn import preprocessing
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# %%
df=df[df.columns.difference(['State', 'County', 'RUCC_2013','group'])]

# %%
number_null_values_percol=df.isnull().sum(axis=0)
#columns with over 50 missing values
cols_with_over_30_null_values=number_null_values_percol[number_null_values_percol>30]
print (cols_with_over_30_null_values.index)
# Out:
# Index(['var1', 'var28', 'var29', 'var41'], dtype='object')

# %%
#drop these columns first
df=df.drop(list(cols_with_over_30_null_values.index), axis=1)
df=df.dropna()

# %%
df.shape
# Out:
# (3113, 52)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3113 entries, 1001 to 56045
# Data columns (total 52 columns):
# frac_uninsured                       3113 non-null float64
# prevalence of diabetes               3113 non-null float64
# prevalence of obesity                3113 non-null float64
# prevalence of physical inactivity    3113 non-null float64
# var10                                3113 non-null float64
# var11                                3113 non-null float64
# var12                                3113 non-null float64
# var13                                3113 non-null float64
# var14                                3113 non-null float64
# var15                                3113 non-null float64
# var16                                3113 non-null float64
# var17                                3113 non-null float64
# var18                                3113 non-null float64
# var19                                3113 non-null float64
# var2                                 3113 non-null float64
# var20                                3113 non-null float64
# var21                                3113 non-null float64
# var22                                3113 non-null float64
# var23                                3113 non-null float64
# var24                                3113 non-null float64
# var27                                3113 non-null float64
# var3                                 3113 non-null float64
# var30                                3113 non-null float64
# var31                                3113 non-null float64
# var32                                3113 non-null float64
# var33                                3113 non-null float64
# var34                                3113 non-null float64
# var35                                3113 non-null float64
# var36                                3113 non-null float64
# var37                                3113 non-null float64
# var38                                3113 non-null float64
# var39                                3113 non-null float64
# var4                                 3113 non-null float64
# var40                                3113 non-null float64
# var44                                3113 non-null float64
# var5                                 3113 non-null float64
# var58                                3113 non-null float64
# var59                                3113 non-null float64
# var6                                 3113 non-null float64
# var60                                3113 non-null float64
# var61                                3113 non-null float64
# var62                                3113 non-null float64
# var63                                3113 non-null float64
# var64                                3113 non-null float64
# var65                                3113 non-null float64
# var66                                3113 non-null float64
# var67                                3113 non-null float64
# var68                                3113 non-null float64
# var69                                3113 non-null float64
# var7                                 3113 non-null float64
# var8                                 3113 non-null float64
# var9                                 3113 non-null float64
# dtypes: float64(52)
# memory usage: 1.3 MB

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_minmax = min_max_scaler.fit_transform(df.values)
normed_df=pd.DataFrame(X_minmax, index=df.index, columns=df.columns)

#normed_data=preprocessing.scale(df_dropnacol)
#normed_df=pd.DataFrame(normed_data, index=df_dropnacol.index, columns=df_dropnacol.columns)

# %% [markdown]
# PCA

# %%
#PCA using Sklearn 
from sklearn.decomposition import PCA

explained_var=list()
for d in range(1,len(normed_df.columns)):
    pca = PCA(n_components=d)
    pca.fit(normed_df)
    explained_var.append(sum(pca.explained_variance_ratio_))

# %%
plt.plot(range(1,len(normed_df.columns)), explained_var)
plt.axhline(y=0.9, color='r')
plt.show()

# %%
#95% of variance can be explained by 22 components out of total 52 variables
pca = PCA(n_components=14)
pca.fit(normed_df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=14, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
data_transformed=pca.transform(normed_df)
df_transformed=pd.DataFrame(data_transformed, index=normed_df.index)
X=df_transformed

# %% [markdown]
# Hierachical clustering

# %% [markdown]
# both average method and centroid method is the best regarding the similarity between compuated distance to real distance

# %%
for method in ['average', 'complete', 'centroid']:
    plt.figure(figsize=(80,20))
    Z = linkage(X, method)
    dendrogram(Z)
    plt.show()

# %% [markdown]
# complete method gives the most tigh clusters

# %%
Z = linkage(X, 'complete')

from collections import Counter

for distance in np.linspace(2, 3, 20):
    labels = fcluster(Z,distance,'distance')
    print (distance, max(Counter(labels).values()), max(labels))
# Out:
# 2.0 568 21
# 2.05263157895 638 18
# 2.10526315789 638 16
# 2.15789473684 976 14
# 2.21052631579 976 13
# 2.26315789474 976 12
# 2.31578947368 976 12
# 2.36842105263 976 12
# 2.42105263158 1138 11
# 2.47368421053 1138 9
# 2.52631578947 1138 8
# 2.57894736842 1138 8
# 2.63157894737 1138 8
# 2.68421052632 1348 7
# 2.73684210526 1348 7
# 2.78947368421 1348 6
# 2.84210526316 1348 6
# 2.89473684211 1348 4
# 2.94736842105 1348 4
# 3.0 1348 3

# %%
labels = fcluster(Z,2.6,'distance')
print (Counter(labels), len(labels))
# Out:
# Counter({5: 1138, 1: 976, 8: 644, 4: 210, 7: 52, 2: 37, 6: 32, 3: 24}) 3113

# %%
group_colors=['grey','red','purple','blue','yellow','turquoise','green','orange']

# %%
from scipy.cluster.hierarchy import cut_tree, dendrogram, fcluster, leaves_list, set_link_color_palette

# %%
import seaborn as sns; sns.set()

set_link_color_palette(group_colors)
plt.figure(figsize=(80,20))
D = dendrogram(Z=Z, color_threshold=2.6, leaf_font_size=12, leaf_rotation=45)
plt.show()

# %% [markdown]
# cut into several clusters to better understand each cluster

# %%
labels = fcluster(Z,2.6,'distance')
Counter(labels)
# Out:
# Counter({1: 976, 2: 37, 3: 24, 4: 210, 5: 1138, 6: 32, 7: 52, 8: 644})

# %%
df['group']=labels

# %%
def Box_plot_by_var(features, data, by, order):
    n=1
    for c in features:
        if is_numeric_dtype(data[c]):
            if order==None:
                sns.boxplot(x=by, y=c, data=data)
            else:
                sns.boxplot(x=by, y=c, data=data, order=order)
            if c in var_info_df.index:
                plt.ylabel(str(var_info_df.loc[c]['Category Name'])+'\n'+str(var_info_df.loc[c]['Sub_subcategory Name']))            
            else: 
                plt.ylabel(c)
            plt.title(c)
            plt.legend()
            plt.show()
            n+=1

# %%
features=df.columns
data=df[df['group'].isin(groups_to_plot)]
Box_plot_by_var(features, data, by='group', order=None)

# %%
race_var_list=list()
for v in var_info_df.index:
    if var_info_df.loc[v]['Category Code']=='SOCIOECONOMIC' and var_info_df.loc[v]['Subcategory Name']=='Race':
        race_var_list.append((var_info_df.loc[v]['Sub_subcategory Name'], v))
print (race_var_list)
# Out:
# [('White', 'var59'), ('Black', 'var60'), ('Hispanic', 'var61'), ('Asian', 'var62'), ('American Indian or Alaska Native', 'var63'), ('Hawaiian or Pacific Islander', 'var64')]

# %%
#stacked percentage plot with standard deviation

import numpy as np
import matplotlib.pyplot as plt



def boxplot_race(groups_to_plot, df):
    N=len(groups_to_plot)
    whitemeans=np.empty(N)
    whitestd=np.empty(N)
    blackmeans=np.empty(N)
    blackstd=np.empty(N)
    asianmeans=np.empty(N)
    asianstd=np.empty(N)
    hispmeans=np.empty(N)
    hispstd=np.empty(N)
    Ame_Ind_Alkmeans=np.empty(N)
    Ame_Ind_Alkstd=np.empty(N)
    Hawa_Islandmeans=np.empty(N)
    Hawa_Islandstd=np.empty(N)

    groups=groups_to_plot

    for n, group in enumerate(groups):
        df_group=df[df['group']==group]
        whitemeans[n]=np.mean(df_group['var59'])
        whitestd[n]=np.std(df_group['var59'])

        blackmeans[n]=np.mean(df_group['var60'])
        blackstd[n]=np.std(df_group['var60'])

        asianmeans[n]=np.mean(df_group['var62'])
        asianstd[n]=np.std(df_group['var62'])

        hispmeans[n]=np.mean(df_group['var61'])
        hispstd[n]=np.std(df_group['var61'])

        Ame_Ind_Alkmeans[n]=np.mean(df_group['var63'])
        Ame_Ind_Alkstd[n]=np.std(df_group['var63'])

        Hawa_Islandmeans[n]=np.mean(df_group['var64'])
        Hawa_Islandstd[n]=np.std(df_group['var64'])

    width = 0.35       # the width of the bars: can also be len(x) sequence

    ind = np.arange(N)

    p1=plt.bar(ind, whitemeans, width, color='r', yerr=whitestd)
    p2=plt.bar(ind, blackmeans, width, color='m', bottom=whitemeans, yerr=blackstd)
    p3=plt.bar(ind, hispmeans, width, color='g', bottom=sum([whitemeans,blackmeans]), yerr=hispstd)
    p4=plt.bar(ind, asianmeans, width, color='y', bottom=sum([whitemeans, blackmeans, hispmeans]), yerr=asianstd)
    p5=plt.bar(ind, Ame_Ind_Alkmeans, width, color='b', bottom=sum([whitemeans, blackmeans, hispmeans, asianmeans]), yerr=Ame_Ind_Alkstd)
    p6=plt.bar(ind, Hawa_Islandmeans, width, color='purple', 
            bottom=np.sum([whitemeans,blackmeans,hispmeans,asianmeans,Ame_Ind_Alkmeans]), yerr=Hawa_Islandstd)

    plt.legend((p1[0], p2[0],p3[0], p4[0],p5[0], p6[0]), ('White', 'Black', 
                                                          'Hispanic', 'Asian','American Indian or Alaska Native', 
                                                          'Hawaiian or Pacific Islander'), bbox_to_anchor=(1.04,1))
    plt.xticks(range(N), ['cluster_'+str(g) for g in groups_to_plot], rotation=45)
    plt.ylim(0, 110)

# %%
boxplot_race([1,2,3,4,5,6,7,8],df)
plt.show()

# %%
age_var_list=list()
for v in var_info_df.index:
    if var_info_df.loc[v]['Category Code']=='SOCIOECONOMIC' and var_info_df.loc[v]['Subcategory Name']=='Age':
        age_var_list.append((var_info_df.loc[v]['Sub_subcategory Name'], v))
print (age_var_list)
# Out:
# [('>=65', 'var65'), ('<18', 'var66')]

# %%
#stacked percentage plot with standard deviation

import numpy as np
import matplotlib.pyplot as plt

N=len(groups_to_plot)

under_18_means=np.empty(N)
under_18_std=np.empty(N)
fr18to65_means=np.empty(N)
fr18to65_std=np.empty(N)
above_65_means=np.empty(N)
above_65_std=np.empty(N)


groups=groups_to_plot

for n, group in enumerate(groups):
    df_group=df[df['group']==group]
    df_group['adult']=100-df_group['var65']-df_group['var66']
    
    under_18_means[n]=np.mean(df_group['var66'])
    under_18_std[n]=np.std(df_group['var66'])
    
    fr18to65_means[n]=np.mean(df_group['adult'])
    fr18to65_std[n]=np.std(df_group['adult'])
    
    above_65_means[n]=np.mean(df_group['var65'])
    above_65_std[n]=np.std(df_group['var65'])

width = 0.35       # the width of the bars: can also be len(x) sequence

ind = np.arange(N)

p1=plt.bar(ind, under_18_means, width, color='y', yerr=under_18_std)
#p2=plt.bar(ind, fr18to65_means, width, color='r', bottom=under_18_means, yerr=fr18to65_std)
p2=plt.bar(ind, above_65_means, width, color='m', bottom=sum([under_18_means]), yerr=above_65_std)


plt.legend((p1[0], p2[0],p3[0]), ('<18 years', '>=65 years'), bbox_to_anchor=(1.04,1))
plt.xticks(range(N),['cluster_'+str(g) for g in groups_to_plot], rotation=45)
plt.ylim(0, 50)
plt.show()
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
features=['prevalence of diabetes','prevalence of obesity','prevalence of physical inactivity']
data=df[df['group'].isin(groups_to_plot)]
Box_plot_by_var(features, data, by='group', order=[1,2,3,4,5,6,7,8])

# %%
features=['var'+str(n) for n in [68,44,34]]
features.append('frac_uninsured')
data=df[df['group'].isin(groups_to_plot)]
Box_plot_by_var(features, data, by='group', order=[1,2,3,4,5,6,7,8])

# %%
print (groups_to_plot)
data=df[df['group'].isin(groups_to_plot)]
data['clusters']=data['group'].apply((lambda x:'cluster_'+str(x)))
data[['clusters']].to_csv('C:/Users/cathy/Capstone_project_1/Datasets/cluster_groups.csv')
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
data['clusters'].unique()
# Out:
# array(['cluster_4', 'cluster_1', 'cluster_6', 'cluster_7', 'cluster_5',
#        'cluster_2', 'cluster_3'], dtype=object)

# %%
data[['clusters']]
# Out:
#         clusters
# FIPS
# 1001   cluster_4
# 1003   cluster_4
# 1005   cluster_4
# 1007   cluster_4
# 1009   cluster_4
# 1011   cluster_1
# 1013   cluster_4
# 1015   cluster_4
# 1017   cluster_4
# 1019   cluster_4
# 1021   cluster_4
# 1023   cluster_4
# 1025   cluster_4
# 1027   cluster_4
# 1029   cluster_4
# 1031   cluster_4
# 1033   cluster_4
# 1035   cluster_4
# 1037   cluster_4
# 1039   cluster_4
# 1041   cluster_4
# 1043   cluster_4
# 1045   cluster_4
# 1047   cluster_1
# 1049   cluster_4
# 1051   cluster_4
# 1053   cluster_4
# 1055   cluster_4
# 1057   cluster_4
# 1059   cluster_4
# ...          ...
# 55129  cluster_7
# 55131  cluster_7
# 55133  cluster_7
# 55135  cluster_7
# 55137  cluster_7
# 55139  cluster_7
# 55141  cluster_7
# 56001  cluster_7
# 56003  cluster_7
# 56005  cluster_7
# 56007  cluster_7
# 56009  cluster_7
# 56011  cluster_7
# 56013  cluster_7
# 56015  cluster_7
# 56017  cluster_7
# 56019  cluster_7
# 56021  cluster_7
# 56023  cluster_7
# 56025  cluster_7
# 56027  cluster_7
# 56029  cluster_7
# 56031  cluster_7
# 56033  cluster_7
# 56035  cluster_7
# 56037  cluster_7
# 56039  cluster_7
# 56041  cluster_7
# 56043  cluster_7
# 56045  cluster_7
#
# [3112 rows x 1 columns]

# %%
var_info_df.keys()
# Out:
# Index(['Unnamed: 0', 'Category Name', 'Category Code', 'Subcategory Name',
#        'Sub_subcategory Name', 'Units'],
#       dtype='object')

# %%
xticks=[str(var_info_df.loc[c]['Category Name'])+'\n'
        +str(var_info_df.loc[c]['Sub_subcategory Name']) if c in var_info_df['Category Name'].keys() else c for c in features]
print (xticks)
# Out:
# ['Socioeconomic Characteristics\nPoverty rate', 'Local Foods\noverall', 'Food Insecurity\nHousehold food insecurity', 'frac_uninsured', 'prevalence of diabetes', 'prevalence of obesity', 'prevalence of physical inactivity']

# %%
import seaborn as sns

sns.set_palette("RdBu_r")


features=['var'+str(n) for n in [2,27,44,34]]
features.append('frac_uninsured')
features.extend(['prevalence of diabetes','prevalence of obesity','prevalence of physical inactivity'])
xticks=[str(var_info_df.loc[c]['Category Name'])+'\n'
        +str(var_info_df.loc[c]['Sub_subcategory Name']) if c in var_info_df['Category Name'].keys() else c for c in features]

print (Z)
normed_df['group']=labels
lut = dict(zip([1,2,3,4,5,6,7,8], group_colors))

row_colors = normed_df['group'].map(lut)
sns.clustermap(normed_df[features], method='average',row_linkage=Z, 
               row_colors=row_colors, figsize=(20,40), xticklabels=xticks)
plt.show()
# Out:
# [[  5.95000000e+02   6.76000000e+02   2.22035103e-02   2.00000000e+00]
#  [  1.48000000e+03   1.49100000e+03   2.77142068e-02   2.00000000e+00]
#  [  2.47300000e+03   2.47600000e+03   3.17709128e-02   2.00000000e+00]
#  ...,
#  [  6.21200000e+03   6.22100000e+03   2.96547549e+00   7.28000000e+02]
#  [  6.21800000e+03   6.22200000e+03   3.05970563e+00   2.07600000e+03]
#  [  6.22000000e+03   6.22300000e+03   3.70680192e+00   3.11300000e+03]]

# %%
features=['var'+str(n) for n in [68,44,34,1]]
data=df[df['group'].isin(groups_to_plot)]
Box_plot_by_var(features, data, by='group', order=[1,11,15,2,8])

# %% [markdown]
# Hierachical clustering of the most diabetes prevalent counties

# %%
df['db_level']=pd.qcut(df['prevalence of diabetes'],6, labels=range(6))
df['ob_level']=pd.qcut(df['prevalence of obesity'],6, labels=range(6))
df['phy_level']=pd.qcut(df['prevalence of physical inactivity'],6, labels=range(6))

# %%
df['db_level']
# Out:
# FIPS
# 1001     4
# 1003     2
# 1005     5
# 1007     5
# 1009     5
# 1011     5
# 1013     5
# 1015     5
# 1017     5
# 1019     4
# 1021     4
# 1023     5
# 1025     5
# 1027     5
# 1029     4
# 1031     5
# 1033     5
# 1035     5
# 1037     5
# 1039     5
# 1041     5
# 1043     5
# 1045     5
# 1047     5
# 1049     4
# 1051     4
# 1053     5
# 1055     5
# 1057     5
# 1059     5
#         ..
# 55129    2
# 55131    0
# 55133    0
# 55135    1
# 55137    2
# 55139    0
# 55141    0
# 56001    0
# 56003    3
# 56005    0
# 56007    0
# 56009    2
# 56011    0
# 56013    1
# 56015    1
# 56017    2
# 56019    0
# 56021    1
# 56023    0
# 56025    1
# 56027    0
# 56029    0
# 56031    0
# 56033    1
# 56035    0
# 56037    0
# 56039    0
# 56041    1
# 56043    3
# 56045    1
# Name: db_level, Length: 3113, dtype: category
# Categories (6, int64): [0 < 1 < 2 < 3 < 4 < 5]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
df_subset=df[(df['db_level']==5) & (df['ob_level']==5)].drop(['group'], axis=1)
X_minmax = min_max_scaler.fit_transform(df_subset.values)
normed_df=pd.DataFrame(X_minmax, index=df_subset.index, columns=df_subset.columns)
# Out:
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#PCA using Sklearn 
from sklearn.decomposition import PCA

explained_var=list()
for d in range(1,len(normed_df.columns)):
    pca = PCA(n_components=d)
    pca.fit(normed_df)
    explained_var.append(sum(pca.explained_variance_ratio_))

# %%
plt.plot(range(1,len(normed_df.columns)), explained_var)
plt.axhline(y=0.9, color='r')
plt.show()

# %%
#95% of variance can be explained by 22 components out of total 52 variables
pca = PCA(n_components=15)
pca.fit(normed_df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=15, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
data_transformed=pca.transform(normed_df)
df_transformed=pd.DataFrame(data_transformed, index=normed_df.index)

# %%
X=df_transformed
distance_way= ['ward', 'single', 'average', 'weighted', 'centroid', 'median']

Z = linkage(X, 'complete')
plt.figure(figsize=(40, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)

plt.show()

# %%
for distance in np.linspace(1, 2, 20):
    labels = fcluster(Z,distance,'distance')
    print (distance, max(Counter(labels).values()), max(labels))
# Out:
# 1.0 33 28
# 1.05263157895 36 24
# 1.10526315789 50 20
# 1.15789473684 50 18
# 1.21052631579 50 17
# 1.26315789474 78 16
# 1.31578947368 78 15
# 1.36842105263 78 13
# 1.42105263158 78 13
# 1.47368421053 115 11
# 1.52631578947 146 9
# 1.57894736842 146 9
# 1.63157894737 211 7
# 1.68421052632 211 7
# 1.73684210526 211 7
# 1.78947368421 211 5
# 1.84210526316 211 5
# 1.89473684211 211 5
# 1.94736842105 213 4
# 2.0 213 4

# %%
labels = fcluster(Z,3.2,'distance')
print (Counter(labels))
# Out:
# Counter({1: 236, 3: 30, 2: 8})

# %%
groups_to_plot=[l for l in Counter(labels).keys() if Counter(labels)[l]>2]

# %%
groups_to_plot
# Out:
# [1, 3, 2]

# %%
df_subset['group']=labels
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#stacked percentage plot with standard deviation

import numpy as np
import matplotlib.pyplot as plt

N=3


whitemeans=np.empty(N)
whitestd=np.empty(N)
blackmeans=np.empty(N)
blackstd=np.empty(N)
asianmeans=np.empty(N)
asianstd=np.empty(N)
hispmeans=np.empty(N)
hispstd=np.empty(N)
Ame_Ind_Alkmeans=np.empty(N)
Ame_Ind_Alkstd=np.empty(N)
Hawa_Islandmeans=np.empty(N)
Hawa_Islandstd=np.empty(N)

groups=[1,2,3]

for n, group in enumerate(groups):
    df_group=df_subset[df_subset['group']==group]
    whitemeans[n]=np.mean(df_group['var59'])
    whitestd[n]=np.std(df_group['var59'])
    
    blackmeans[n]=np.mean(df_group['var60'])
    blackstd[n]=np.std(df_group['var60'])
    
    asianmeans[n]=np.mean(df_group['var62'])
    asianstd[n]=np.std(df_group['var62'])
    
    hispmeans[n]=np.mean(df_group['var61'])
    hispstd[n]=np.std(df_group['var61'])
    
    Ame_Ind_Alkmeans[n]=np.mean(df_group['var63'])
    Ame_Ind_Alkstd[n]=np.std(df_group['var63'])
    
    Hawa_Islandmeans[n]=np.mean(df_group['var64'])
    Hawa_Islandstd[n]=np.std(df_group['var64'])

width = 0.35       # the width of the bars: can also be len(x) sequence

ind = np.arange(N)

p1=plt.bar(ind, whitemeans, width, color='r', yerr=whitestd)
p2=plt.bar(ind, blackmeans, width, color='m', bottom=whitemeans, yerr=blackstd)
p3=plt.bar(ind, hispmeans, width, color='g', bottom=sum([whitemeans,blackmeans]), yerr=hispstd)
p4=plt.bar(ind, asianmeans, width, color='y', bottom=sum([whitemeans, blackmeans, hispmeans]), yerr=asianstd)
p5=plt.bar(ind, Ame_Ind_Alkmeans, width, color='b', bottom=sum([whitemeans, blackmeans, hispmeans, asianmeans]), yerr=Ame_Ind_Alkstd)
p6=plt.bar(ind, Hawa_Islandmeans, width, color='purple', 
        bottom=np.sum([whitemeans,blackmeans,hispmeans,asianmeans,Ame_Ind_Alkmeans]), yerr=Hawa_Islandstd)

plt.legend((p1[0], p2[0],p3[0], p4[0],p5[0], p6[0]), ('White', 'Black', 
                                                      'Hispanic', 'Asian','American Indian or Alaska Native', 
                                                      'Hawaiian or Pacific Islander'), bbox_to_anchor=(1.04,1))
plt.xticks(range(N), ['group'+str(i) for i in range(1,N+1)], rotation=45)
plt.ylim(0, 110)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N=len(groups_to_plot)

under_18_means=np.empty(N)
under_18_std=np.empty(N)
fr18to65_means=np.empty(N)
fr18to65_std=np.empty(N)
above_65_means=np.empty(N)
above_65_std=np.empty(N)


groups=[1,2,3]

for n, group in enumerate(groups):
    df_group=df_subset[df_subset['group']==group]
    df_group['adult']=100-df_group['var65']-df_group['var66']
    
    under_18_means[n]=np.mean(df_group['var66'])
    under_18_std[n]=np.std(df_group['var66'])
    
    fr18to65_means[n]=np.mean(df_group['adult'])
    fr18to65_std[n]=np.std(df_group['adult'])
    
    above_65_means[n]=np.mean(df_group['var65'])
    above_65_std[n]=np.std(df_group['var65'])

width = 0.35       # the width of the bars: can also be len(x) sequence

ind = np.arange(N)

p1=plt.bar(ind, under_18_means, width, color='y', yerr=under_18_std)
#p2=plt.bar(ind, fr18to65_means, width, color='r', bottom=under_18_means, yerr=fr18to65_std)
p2=plt.bar(ind, above_65_means, width, color='m', bottom=sum([under_18_means]), yerr=above_65_std)


plt.legend((p1[0], p2[0],p3[0]), ('<18 years', '>=65 years'), bbox_to_anchor=(1.04,1))
plt.xticks(range(N), ['group'+str(i) for i in range(1,N+1)], rotation=45)
plt.ylim(0, 50)
plt.show()
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
features=['prevalence of diabetes','prevalence of obesity','prevalence of physical inactivity']
data=df_subset[df_subset['group'].isin(groups_to_plot)]
Box_plot_by_var(features, data, by='group', order=[1,2,3])

# %%
features=['var'+str(n) for n in [68,44,34]]
features.append('frac_uninsured')
data=df_subset[df_subset['group'].isin(groups_to_plot)]
Box_plot_by_var(features, data, by='group', order=[1,2,3])

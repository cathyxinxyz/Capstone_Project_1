# %% [markdown]
# This document contains the codes that preprocess the data for regression analysis and build model of linear regression using variables from the integrated datasets.
#
# Dependent variable: prevalence of obesity
#
# The contents include:
#
# i. Preprocessing data
# ii. construct linear regression model
# iii. collinearity
# iv. Detecting outliers and high leverage points
# v. residual diagnosis:
#      a. do errors follow normal distribution?
#      b. is mean of errors zero?
#      c. do errors have the same variance?
#      d. are errors independent of each other?
# vi. model assessment and interpretation

# %%
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
#read the complete dataset
url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/Combined_data.csv'
df=pd.read_csv(url,index_col='FIPS',encoding="ISO-8859-1")

# %%
#standardize data: (x-mean(x))/std
from sklearn import preprocessing
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

scaled_columns=[c for c in df.columns if is_numeric_dtype(df[c])]
df_for_scale=df[scaled_columns].dropna()
X=df_for_scale.values
scaler=  preprocessing.StandardScaler()
X_scaled = scaler.fit_transform(X)
scaled_df = pd.DataFrame(X_scaled, index=df_for_scale.index, columns=df_for_scale.columns)

# %%
#replace space in variable names with _
scaled_df.rename(columns=lambda x:'above'.join(x.split('>=')), inplace=True)
scaled_df.rename(columns=lambda x:'under'.join(x.split('<')), inplace=True)
scaled_df.rename(columns=lambda x:'_'.join(x.split(' ')), inplace=True)

# %%
vars=list(scaled_df.columns.difference(['prevalence_of_diabetes',
                                             'prevalence_of_obesity',
                                             'Adult_db', 
                                             'Adult_ob']))
features='+'.join(vars)
y, X = dmatrices('prevalence_of_obesity ~1+' + features, scaled_df, return_type='dataframe')

mod = smf.OLS(y, X)
result=mod.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     prevalence_of_obesity   R-squared:                       0.616
# Model:                               OLS   Adj. R-squared:                  0.613
# Method:                    Least Squares   F-statistic:                     182.3
# Date:                   Sat, 30 Dec 2017   Prob (F-statistic):               0.00
# Time:                           09:20:24   Log-Likelihood:                -2913.6
# No. Observations:                   3098   AIC:                             5883.
# Df Residuals:                       3070   BIC:                             6052.
# Df Model:                             27
# Covariance Type:               nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -7.459e-16      0.011  -6.67e-14      1.000      -0.022       0.022
# American_Indian_or_Alaska_Native      0.2020      0.100      2.023      0.043       0.006       0.398
# Asian                                -0.0550      0.037     -1.485      0.138      -0.128       0.018
# Assistance                            0.0469      0.013      3.675      0.000       0.022       0.072
# Black                                 0.4379      0.184      2.386      0.017       0.078       0.798
# Convenience                          -0.0130      0.014     -0.958      0.338      -0.040       0.014
# Farm                                  0.0056      0.012      0.455      0.649      -0.018       0.030
# Fast_food                            -0.0365      0.014     -2.640      0.008      -0.064      -0.009
# Full_service                         -0.0763      0.016     -4.748      0.000      -0.108      -0.045
# Grocery                              -0.0586      0.016     -3.613      0.000      -0.090      -0.027
# Hawaiian_or_Pacific_Islander          0.0410      0.019      2.207      0.027       0.005       0.077
# Hispanic                              0.0703      0.168      0.419      0.675      -0.258       0.399
# Low_Access_Child                     -0.1042      0.060     -1.724      0.085      -0.223       0.014
# Low_Access_Overall                    0.1752      0.088      1.998      0.046       0.003       0.347
# Low_Access_Seniors                   -0.1247      0.045     -2.777      0.006      -0.213      -0.037
# Low_Access_low_income                 0.0333      0.035      0.948      0.343      -0.036       0.102
# Low_insecurity                        0.0764      0.034      2.236      0.025       0.009       0.143
# Poverty_rate                          0.0070      0.020      0.349      0.727      -0.032       0.046
# Recreation_facility                  -0.0409      0.013     -3.208      0.001      -0.066      -0.016
# SNAP_store                            0.0334      0.016      2.054      0.040       0.002       0.065
# Specialized                           0.0038      0.012      0.309      0.757      -0.020       0.028
# Supercenter                           0.0477      0.012      3.949      0.000       0.024       0.071
# Very_low_insecurity                  -0.0357      0.035     -1.033      0.302      -0.103       0.032
# WIC_store                             0.0446      0.016      2.744      0.006       0.013       0.076
# White                                 0.3847      0.251      1.534      0.125      -0.107       0.876
# above65                              -0.0227      0.022     -1.049      0.294      -0.065       0.020
# prevalence_of_physical_inactivity     0.4976      0.016     30.185      0.000       0.465       0.530
# under18                               0.1187      0.020      5.853      0.000       0.079       0.158
# ==============================================================================
# Omnibus:                       15.001   Durbin-Watson:                   1.497
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.396
# Skew:                           0.124   Prob(JB):                     0.000275
# Kurtosis:                       3.256   Cond. No.                         69.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif
# Out:
#     VIF Factor                           features
# 0     1.000000                          Intercept
# 1    79.727772   American_Indian_or_Alaska_Native
# 2    10.950420                              Asian
# 3     1.300721                         Assistance
# 4   269.274453                              Black
# 5     1.471712                        Convenience
# 6     1.205969                               Farm
# 7     1.528162                          Fast_food
# 8     2.061382                       Full_service
# 9     2.103192                            Grocery
# 10    2.762183       Hawaiian_or_Pacific_Islander
# 11  224.521914                           Hispanic
# 12   29.219633                   Low_Access_Child
# 13   61.484808                 Low_Access_Overall
# 14   16.121865                 Low_Access_Seniors
# 15    9.846001              Low_Access_low_income
# 16    9.327503                     Low_insecurity
# 17    3.219426                       Poverty_rate
# 18    1.296974                Recreation_facility
# 19    2.119242                         SNAP_store
# 20    1.185734                        Specialized
# 21    1.165531                        Supercenter
# 22    9.537597                Very_low_insecurity
# 23    2.110844                          WIC_store
# 24  502.662320                              White
# 25    3.752841                            above65
# 26    2.172718  prevalence_of_physical_inactivity
# 27    3.287608                            under18

# %% [markdown]
# The results incidate a strong multicollinearity among variables that quantify
# the race/ethnicity composition: White, Black, Hispanic and American_Indian_or_Alaska_Native
# as indicated in the section of exploratory data analysis, the percentage of White people in the population
# negatively correlates with percentage of Black people, Hispanic people, or American_Indian_or_Alaska_Native people
#
# In addition, there is also moderate multicollinearity among variables Low_Access_Overall,Low_Access_Child, Low_Access_Seniors, Low_Access_Overall, Low_Access_low_income, as indicated in exploratory analysis
#
# Lastly, low_security and very_low_security have a moderate level of
# multicollinearity, which is reasonable since very low food security is a subcategory of low food security.
#
# In order to remove the variables with high multicollinearity, I remove variables Black, Hispanic and American_Indian_or_Alaska_Native, Asian, Low_Access_Child, Low_Access_Seniors, Low_Access_low_income, Very_low_insecurity

# %%
vars=list(set(vars).difference(set(['Black','Hispanic','Asian','American_Indian_or_Alaska_Native',
                                    'Low_Access_Child','Low_Access_Seniors','Low_Access_low_income',
                                    'Very_low_insecurity'])))

# %%
features='+'.join(vars)
y, X = dmatrices('prevalence_of_obesity ~1+' + features, scaled_df, return_type='dataframe')

mod = sm.OLS(y, X)
result=mod.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     prevalence_of_obesity   R-squared:                       0.557
# Model:                               OLS   Adj. R-squared:                  0.554
# Method:                    Least Squares   F-statistic:                     203.4
# Date:                   Sat, 30 Dec 2017   Prob (F-statistic):               0.00
# Time:                           09:25:56   Log-Likelihood:                -3135.9
# No. Observations:                   3098   AIC:                             6312.
# Df Residuals:                       3078   BIC:                             6433.
# Df Model:                             19
# Covariance Type:               nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -7.858e-16      0.012  -6.55e-14      1.000      -0.024       0.024
# SNAP_store                            0.0710      0.017      4.128      0.000       0.037       0.105
# Poverty_rate                          0.0636      0.019      3.350      0.001       0.026       0.101
# Fast_food                            -0.0515      0.015     -3.518      0.000      -0.080      -0.023
# Recreation_facility                  -0.0230      0.014     -1.698      0.090      -0.050       0.004
# prevalence_of_physical_inactivity     0.5902      0.017     35.272      0.000       0.557       0.623
# above65                              -0.1001      0.017     -5.750      0.000      -0.134      -0.066
# Low_insecurity                        0.0338      0.013      2.579      0.010       0.008       0.060
# Full_service                         -0.0953      0.017     -5.605      0.000      -0.129      -0.062
# Low_Access_Overall                    0.0065      0.013      0.487      0.626      -0.020       0.033
# Assistance                            0.0309      0.013      2.325      0.020       0.005       0.057
# Convenience                           0.0229      0.014      1.607      0.108      -0.005       0.051
# Supercenter                           0.0446      0.013      3.454      0.001       0.019       0.070
# White                                 0.0530      0.017      3.051      0.002       0.019       0.087
# under18                               0.0643      0.016      4.037      0.000       0.033       0.096
# Grocery                              -0.0657      0.017     -3.806      0.000      -0.100      -0.032
# Specialized                           0.0140      0.013      1.075      0.283      -0.012       0.039
# Hawaiian_or_Pacific_Islander         -0.0220      0.012     -1.789      0.074      -0.046       0.002
# WIC_store                             0.0511      0.017      3.071      0.002       0.018       0.084
# Farm                                  0.0163      0.013      1.239      0.215      -0.009       0.042
# ==============================================================================
# Omnibus:                       20.516   Durbin-Watson:                   1.417
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.359
# Skew:                           0.174   Prob(JB):                     2.30e-05
# Kurtosis:                       3.210   Cond. No.                         3.69
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# After removing the variables that have collinearity with other variables, R square decreases from 0.616 to 0.557, which is reasonable since I only use a subset of the variables in the model. In addition, coefficients of several variables become statistically significant (p value falls under 0.05).

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif
# Out:
#     VIF Factor                           features
# 0     1.000000                          Intercept
# 1     2.056158                         SNAP_store
# 2     2.501780                       Poverty_rate
# 3     1.487055                          Fast_food
# 4     1.271987                Recreation_facility
# 5     1.943646  prevalence_of_physical_inactivity
# 6     2.103695                            above65
# 7     1.195222                     Low_insecurity
# 8     2.006019                       Full_service
# 9     1.240966                 Low_Access_Overall
# 10    1.227911                         Assistance
# 11    1.408443                        Convenience
# 12    1.156137                        Supercenter
# 13    2.093495                              White
# 14    1.763874                            under18
# 15    2.069901                            Grocery
# 16    1.175460                        Specialized
# 17    1.048565       Hawaiian_or_Pacific_Islander
# 18    1.924098                          WIC_store
# 19    1.196224                               Farm

# %% [markdown]
# vif test shows that there is no sever multicollinearity this time

# %% [markdown]
# The regression results indicate that there are several variables whose coefficients are not statistically significant (p value >0.05). Therefore, I remove the insignificant independent variables ('Recreation_facility', 'Low_Access_Overall' and 'Convenience', 'Specialized', 'Hawaiian_or_Pacific_Islander', 'Farm')

# %%
vars=list(set(vars).difference(set(['Recreation_facility', 'Low_Access_Overall','Convenience', 'Specialized', 'Hawaiian_or_Pacific_Islander', 'Farm'])))

# %%
features='+'.join(vars)
y, X = dmatrices('prevalence_of_obesity ~1+' + features, scaled_df, return_type='dataframe')

mod = smf.OLS(y, X)
result=mod.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     prevalence_of_obesity   R-squared:                       0.555
# Model:                               OLS   Adj. R-squared:                  0.553
# Method:                    Least Squares   F-statistic:                     295.9
# Date:                   Sat, 30 Dec 2017   Prob (F-statistic):               0.00
# Time:                           09:31:59   Log-Likelihood:                -3141.6
# No. Observations:                   3098   AIC:                             6311.
# Df Residuals:                       3084   BIC:                             6396.
# Df Model:                             13
# Covariance Type:               nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -7.858e-16      0.012  -6.54e-14      1.000      -0.024       0.024
# SNAP_store                            0.0812      0.017      4.917      0.000       0.049       0.114
# Poverty_rate                          0.0687      0.019      3.667      0.000       0.032       0.105
# Fast_food                            -0.0582      0.014     -4.058      0.000      -0.086      -0.030
# prevalence_of_physical_inactivity     0.5952      0.016     36.511      0.000       0.563       0.627
# above65                              -0.0909      0.017     -5.318      0.000      -0.124      -0.057
# Low_insecurity                        0.0337      0.013      2.569      0.010       0.008       0.059
# Full_service                         -0.0834      0.016     -5.211      0.000      -0.115      -0.052
# Assistance                            0.0349      0.013      2.667      0.008       0.009       0.061
# Supercenter                           0.0433      0.013      3.360      0.001       0.018       0.069
# White                                 0.0567      0.017      3.360      0.001       0.024       0.090
# under18                               0.0692      0.016      4.372      0.000       0.038       0.100
# Grocery                              -0.0618      0.017     -3.623      0.000      -0.095      -0.028
# WIC_store                             0.0517      0.017      3.129      0.002       0.019       0.084
# ==============================================================================
# Omnibus:                       20.127   Durbin-Watson:                   1.417
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.969
# Skew:                           0.172   Prob(JB):                     2.80e-05
# Kurtosis:                       3.211   Cond. No.                         3.38
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# After removing insignificant independent variables, R square slightly decreases from 0.557 to 0.555, indicating removing these variables does not severely reduce model fit. The next step is to check any possible interactions.

# %%
from itertools import combinations
vars_with_interaction=list()
vars_with_interaction.extend(vars)
for var_pair in combinations(vars,2):
    scaled_df[var_pair[0]+'_'+var_pair[1]]=scaled_df[var_pair[0]]*scaled_df[var_pair[1]]
    vars_with_interaction.append(var_pair[0]+'_'+var_pair[1])

# %%
features='+'.join(vars_with_interaction)
y, X = dmatrices('prevalence_of_obesity ~1+' + features, scaled_df, return_type='dataframe')

mod = smf.OLS(y, X)
result=mod.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     prevalence_of_obesity   R-squared:                       0.651
# Model:                               OLS   Adj. R-squared:                  0.640
# Method:                    Least Squares   F-statistic:                     61.59
# Date:                   Sat, 30 Dec 2017   Prob (F-statistic):               0.00
# Time:                           09:41:27   Log-Likelihood:                -2765.7
# No. Observations:                   3098   AIC:                             5715.
# Df Residuals:                       3006   BIC:                             6271.
# Df Model:                             91
# Covariance Type:               nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            0.0389      0.018      2.149      0.032       0.003       0.074
# SNAP_store                                           0.0797      0.020      4.023      0.000       0.041       0.119
# Poverty_rate                                         0.0355      0.022      1.640      0.101      -0.007       0.078
# Fast_food                                           -0.0331      0.016     -2.072      0.038      -0.064      -0.002
# prevalence_of_physical_inactivity                    0.5552      0.016     33.725      0.000       0.523       0.587
# above65                                             -0.1733      0.021     -8.440      0.000      -0.214      -0.133
# Low_insecurity                                       0.0600      0.014      4.352      0.000       0.033       0.087
# Full_service                                        -0.1351      0.025     -5.376      0.000      -0.184      -0.086
# Assistance                                           0.0070      0.013      0.534      0.593      -0.019       0.033
# Supercenter                                          0.0622      0.014      4.349      0.000       0.034       0.090
# White                                                0.1147      0.019      6.022      0.000       0.077       0.152
# under18                                              0.0122      0.020      0.625      0.532      -0.026       0.051
# Grocery                                             -0.0794      0.025     -3.178      0.001      -0.128      -0.030
# WIC_store                                            0.1213      0.026      4.730      0.000       0.071       0.172
# SNAP_store_Poverty_rate                             -0.0236      0.021     -1.137      0.256      -0.064       0.017
# SNAP_store_Fast_food                                -0.0162      0.016     -0.991      0.322      -0.048       0.016
# SNAP_store_prevalence_of_physical_inactivity        -0.0351      0.020     -1.730      0.084      -0.075       0.005
# SNAP_store_above65                                   0.0199      0.022      0.917      0.359      -0.023       0.062
# SNAP_store_Low_insecurity                           -0.0071      0.019     -0.379      0.705      -0.044       0.030
# SNAP_store_Full_service                              0.0180      0.019      0.968      0.333      -0.018       0.055
# SNAP_store_Assistance                               -0.0556      0.016     -3.443      0.001      -0.087      -0.024
# SNAP_store_Supercenter                            8.747e-05      0.016      0.006      0.996      -0.031       0.031
# SNAP_store_White                                    -0.0275      0.019     -1.439      0.150      -0.065       0.010
# SNAP_store_under18                                   0.0133      0.019      0.699      0.485      -0.024       0.050
# SNAP_store_Grocery                                   0.0042      0.012      0.356      0.722      -0.019       0.027
# SNAP_store_WIC_store                                -0.0267      0.009     -2.818      0.005      -0.045      -0.008
# Poverty_rate_Fast_food                               0.0691      0.020      3.373      0.001       0.029       0.109
# Poverty_rate_prevalence_of_physical_inactivity       0.0166      0.020      0.809      0.418      -0.024       0.057
# Poverty_rate_above65                                 0.0182      0.023      0.793      0.428      -0.027       0.063
# Poverty_rate_Low_insecurity                         -0.0058      0.019     -0.300      0.764      -0.044       0.032
# Poverty_rate_Full_service                           -0.0719      0.029     -2.512      0.012      -0.128      -0.016
# Poverty_rate_Assistance                              0.0457      0.021      2.216      0.027       0.005       0.086
# Poverty_rate_Supercenter                            -0.0327      0.021     -1.569      0.117      -0.074       0.008
# Poverty_rate_White                                  -0.0233      0.015     -1.508      0.132      -0.054       0.007
# Poverty_rate_under18                                 0.0293      0.015      1.974      0.049       0.000       0.059
# Poverty_rate_Grocery                                 0.0033      0.022      0.151      0.880      -0.040       0.046
# Poverty_rate_WIC_store                               0.0273      0.020      1.353      0.176      -0.012       0.067
# Fast_food_prevalence_of_physical_inactivity         -0.0024      0.021     -0.116      0.908      -0.043       0.038
# Fast_food_above65                                    0.0097      0.019      0.512      0.608      -0.027       0.047
# Fast_food_Low_insecurity                            -0.0083      0.017     -0.480      0.631      -0.042       0.026
# Fast_food_Full_service                               0.0098      0.005      2.033      0.042       0.000       0.019
# Fast_food_Assistance                                -0.0124      0.015     -0.834      0.404      -0.041       0.017
# Fast_food_Supercenter                               -0.0166      0.011     -1.580      0.114      -0.037       0.004
# Fast_food_White                                      0.0202      0.019      1.068      0.286      -0.017       0.057
# Fast_food_under18                                   -0.0105      0.016     -0.674      0.501      -0.041       0.020
# Fast_food_Grocery                                   -0.0139      0.011     -1.256      0.209      -0.036       0.008
# Fast_food_WIC_store                                  0.0142      0.012      1.183      0.237      -0.009       0.038
# prevalence_of_physical_inactivity_above65           -0.0854      0.021     -4.011      0.000      -0.127      -0.044
# prevalence_of_physical_inactivity_Low_insecurity    -0.0620      0.017     -3.627      0.000      -0.095      -0.028
# prevalence_of_physical_inactivity_Full_service       0.0618      0.023      2.670      0.008       0.016       0.107
# prevalence_of_physical_inactivity_Assistance        -0.0021      0.017     -0.130      0.897      -0.035       0.030
# prevalence_of_physical_inactivity_Supercenter       -0.0230      0.017     -1.380      0.168      -0.056       0.010
# prevalence_of_physical_inactivity_White             -0.2049      0.020    -10.494      0.000      -0.243      -0.167
# prevalence_of_physical_inactivity_under18           -0.0825      0.019     -4.342      0.000      -0.120      -0.045
# prevalence_of_physical_inactivity_Grocery            0.0064      0.025      0.258      0.796      -0.042       0.055
# prevalence_of_physical_inactivity_WIC_store         -0.0426      0.022     -1.950      0.051      -0.086       0.000
# above65_Low_insecurity                               0.0226      0.019      1.192      0.233      -0.015       0.060
# above65_Full_service                                -0.0007      0.020     -0.035      0.972      -0.039       0.038
# above65_Assistance                                  -0.0138      0.018     -0.766      0.444      -0.049       0.022
# above65_Supercenter                                 -0.0447      0.018     -2.442      0.015      -0.081      -0.009
# above65_White                                        0.1538      0.020      7.684      0.000       0.115       0.193
# above65_under18                                      0.0094      0.012      0.789      0.430      -0.014       0.033
# above65_Grocery                                     -0.0139      0.020     -0.703      0.482      -0.053       0.025
# above65_WIC_store                                   -0.0518      0.020     -2.654      0.008      -0.090      -0.014
# Low_insecurity_Full_service                         -0.0010      0.022     -0.047      0.963      -0.044       0.042
# Low_insecurity_Assistance                           -0.0278      0.013     -2.066      0.039      -0.054      -0.001
# Low_insecurity_Supercenter                           0.0027      0.014      0.195      0.846      -0.024       0.030
# Low_insecurity_White                                -0.0331      0.018     -1.809      0.071      -0.069       0.003
# Low_insecurity_under18                              -0.0054      0.018     -0.308      0.758      -0.040       0.029
# Low_insecurity_Grocery                              -0.0218      0.021     -1.019      0.308      -0.064       0.020
# Low_insecurity_WIC_store                             0.0591      0.020      2.954      0.003       0.020       0.098
# Full_service_Assistance                              0.0091      0.017      0.539      0.590      -0.024       0.042
# Full_service_Supercenter                            -0.0118      0.020     -0.597      0.551      -0.050       0.027
# Full_service_White                                  -0.0446      0.026     -1.691      0.091      -0.096       0.007
# Full_service_under18                                -0.0279      0.019     -1.473      0.141      -0.065       0.009
# Full_service_Grocery                                 0.0154      0.007      2.215      0.027       0.002       0.029
# Full_service_WIC_store                           -2.807e-05      0.014     -0.002      0.998      -0.027       0.027
# Assistance_Supercenter                               0.0119      0.013      0.910      0.363      -0.014       0.038
# Assistance_White                                     0.1052      0.019      5.418      0.000       0.067       0.143
# Assistance_under18                                   0.0353      0.016      2.175      0.030       0.003       0.067
# Assistance_Grocery                                   0.0218      0.017      1.289      0.198      -0.011       0.055
# Assistance_WIC_store                                 0.0306      0.018      1.740      0.082      -0.004       0.065
# Supercenter_White                                    0.0126      0.019      0.651      0.515      -0.025       0.050
# Supercenter_under18                                 -0.0296      0.018     -1.616      0.106      -0.065       0.006
# Supercenter_Grocery                                  0.0129      0.023      0.561      0.575      -0.032       0.058
# Supercenter_WIC_store                               -0.0029      0.025     -0.116      0.908      -0.052       0.046
# White_under18                                        0.0454      0.016      2.860      0.004       0.014       0.077
# White_Grocery                                        0.0560      0.022      2.577      0.010       0.013       0.099
# White_WIC_store                                     -0.0085      0.021     -0.399      0.690      -0.050       0.033
# under18_Grocery                                      0.0249      0.018      1.399      0.162      -0.010       0.060
# under18_WIC_store                                   -0.0459      0.018     -2.499      0.013      -0.082      -0.010
# Grocery_WIC_store                                   -0.0106      0.008     -1.355      0.176      -0.026       0.005
# ==============================================================================
# Omnibus:                       13.887   Durbin-Watson:                   1.541
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.977
# Skew:                           0.154   Prob(JB):                     0.000923
# Kurtosis:                       3.117   Cond. No.                         31.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# After including all the possible interaction terms, R square increases from 0.555 to 0.651, which suggests improvement in model fitting. I remove all insignificant interaction terms to better show these results

# %%
for i in range(5):
    alpha = 0.05
    #result.summary().tables[1].data[1:]
    param_table= pd.DataFrame(data = [x for x in result.summary().tables[1].data[1:] if (float(x[4]) < alpha) | (x[0] in vars)], columns = result.summary().tables[1].data[0])
    vars_to_keep=list(param_table[''])[1:]
    features='+'.join(vars_to_keep)
    y, X = dmatrices('prevalence_of_obesity ~1+' + features, scaled_df, return_type='dataframe')

    mod = smf.OLS(y, X)
    result=mod.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     prevalence_of_obesity   R-squared:                       0.639
# Model:                               OLS   Adj. R-squared:                  0.636
# Method:                    Least Squares   F-statistic:                     187.3
# Date:                   Sat, 30 Dec 2017   Prob (F-statistic):               0.00
# Time:                           09:54:14   Log-Likelihood:                -2817.6
# No. Observations:                   3098   AIC:                             5695.
# Df Residuals:                       3068   BIC:                             5876.
# Df Model:                             29
# Covariance Type:               nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            0.0387      0.014      2.721      0.007       0.011       0.067
# SNAP_store                                           0.0807      0.016      4.916      0.000       0.049       0.113
# Poverty_rate                                         0.0467      0.018      2.568      0.010       0.011       0.082
# Fast_food                                           -0.0411      0.014     -2.997      0.003      -0.068      -0.014
# prevalence_of_physical_inactivity                    0.5626      0.015     36.762      0.000       0.533       0.593
# above65                                             -0.1775      0.017    -10.218      0.000      -0.212      -0.143
# Low_insecurity                                       0.0610      0.013      4.868      0.000       0.036       0.086
# Full_service                                        -0.0977      0.018     -5.354      0.000      -0.133      -0.062
# Assistance                                           0.0216      0.012      1.795      0.073      -0.002       0.045
# Supercenter                                          0.0380      0.012      3.225      0.001       0.015       0.061
# White                                                0.1113      0.017      6.694      0.000       0.079       0.144
# under18                                              0.0157      0.017      0.905      0.366      -0.018       0.050
# Grocery                                             -0.0921      0.017     -5.511      0.000      -0.125      -0.059
# WIC_store                                            0.1044      0.018      5.781      0.000       0.069       0.140
# SNAP_store_WIC_store                                -0.0258      0.005     -5.322      0.000      -0.035      -0.016
# Poverty_rate_under18                                 0.0504      0.012      4.383      0.000       0.028       0.073
# Fast_food_Full_service                               0.0060      0.002      2.718      0.007       0.002       0.010
# prevalence_of_physical_inactivity_above65           -0.0937      0.014     -6.609      0.000      -0.122      -0.066
# prevalence_of_physical_inactivity_Low_insecurity    -0.0757      0.013     -6.042      0.000      -0.100      -0.051
# prevalence_of_physical_inactivity_Full_service       0.0497      0.013      3.824      0.000       0.024       0.075
# prevalence_of_physical_inactivity_White             -0.2341      0.013    -18.705      0.000      -0.259      -0.210
# prevalence_of_physical_inactivity_under18           -0.1018      0.016     -6.548      0.000      -0.132      -0.071
# above65_White                                        0.1377      0.015      8.936      0.000       0.108       0.168
# above65_WIC_store                                   -0.0310      0.008     -3.894      0.000      -0.047      -0.015
# Low_insecurity_Assistance                           -0.0282      0.012     -2.417      0.016      -0.051      -0.005
# Low_insecurity_WIC_store                             0.0526      0.013      3.895      0.000       0.026       0.079
# Full_service_Grocery                                 0.0172      0.005      3.714      0.000       0.008       0.026
# Assistance_White                                     0.0911      0.013      6.955      0.000       0.065       0.117
# Assistance_under18                                   0.0365      0.013      2.904      0.004       0.012       0.061
# White_under18                                        0.0442      0.013      3.336      0.001       0.018       0.070
# ==============================================================================
# Omnibus:                        8.842   Durbin-Watson:                   1.530
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                8.808
# Skew:                           0.123   Prob(JB):                       0.0122
# Kurtosis:                       3.089   Cond. No.                         18.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# After removing all insignificant interaction terms, I see some interesting patterns. Firstly, coefficients of main effects of several variables become insignificant, such as 'under18' and 'Assistance'. However, the interaction terms that involve these two variables are still statistically significant. For example, the interaction term between Poverty_rate and under18 and interaction term between low food security and food assistance: Low_insecurity_Assistance.

# %% [markdown]
# Codes to plot the map of the variables by US county

# %%
#load all libraries
library(choroplethr)
library(choroplethrMaps)
require(RCurl)
library(plyr)
library(ggplot2)
library(dplyr)
library(reshape2)
library(gridExtra)
library(knitr)
library(repr)

# %%
#construct a function that return the list of maps of variables at US county level

function Map_list(var_list, df, var_info){
    map_plot_list<-list()
    for (n in seq (1:length(var_list))) {
      var=var_list[[n]]
      print (var)
      df_map<-df[,c("FIPS",var)]
      df_map<-na.omit(df_map)

      colnames(df_map)<-c("region","value")

      title<-paste(var_info[var, ]$Category.Name, 
                   var_info[var, ]$Subcategory.Name, 
                   var_info[var, ]$Year,
                   sep="\n")

      cc=county_choropleth(df_map,
                        title =title, 
                        legend = var_info[var, ]$Units)
      map_plot_list[[n]]<-cc
    }
    return (map_plot_list)
}

# %%
url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/Food_atlas/variable_info.csv'
var_info <-read.csv(text=getURL(url), sep=',',header=T)
print (colnames(var_info))
var_info<-var_info[,c("Category.Name","Sub_subcategory.Name","Year","Variable.Code","Units")]
#rownames(var_info) <- var_info$Variable.Code
# Out:
# [1] "Category.Name"        "Category.Code"        "Subcategory.Name"
# [4] "Sub_subcategory.Name" "Year"                 "Variable.Code"
# [7] "Geography"            "Units"

# %%
colnames(var_info)<-c("Category","Subcategory","Year","Variable","Units")

# %%
rownames(var_info) <- var_info$Variable

# %%
url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/Food_atlas/df_tp_1.csv'
df_tp <-read.csv(text=getURL(url), sep=',',header=T)

# %%
url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/CDC/Diabetes_prevalence.csv'
df_db <-read.csv(text=getURL(url), sep=',',header=T)

# %%
url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/CDC/Obesity_prevalence.csv'
df_ob <-read.csv(text=getURL(url), sep=',',header=T)

# %%
url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/CDC/Physical_inactive_prevalence.csv'
df_phy <-read.csv(text=getURL(url), sep=',',header=T)

# %%
var_access<-na.omit(colnames(df_tp)[var_info[colnames(df_tp),]$Category.Code == 'ACCESS'])
var_assist<-na.omit(colnames(df_tp)[var_info[colnames(df_tp),]$Category.Code == 'ASSISTANCE'])
var_rest<-na.omit(colnames(df_tp)[var_info[colnames(df_tp),]$Category.Code == 'RESTAURANTS'])
var_se<-na.omit(colnames(df_tp)[var_info[colnames(df_tp),]$Category.Code =='SOCIOECONOMIC'])
var_sto<-na.omit(colnames(df_tp)[var_info[colnames(df_tp),]$Category.Code =='STORES'])
var_ins<-na.omit(colnames(df_tp)[var_info[colnames(df_tp),]$Category.Code =='INSECURITY'])
var_loc<-na.omit(colnames(df_tp)[var_info[colnames(df_tp),]$Category.Code =='LOCAL'])
var_rec<-na.omit(colnames(df_tp)[var_info[colnames(df_tp),]$Category.Code =='HEALTH'])

# %%
#mapping variables that belong to ACCESS category

# %%
plts[[1]]
plts[[2]]
plts[[3]]
plts[[4]]
plts[[5]]
plts[[6]]
plts[[7]]
plts[[8]]
plts[[9]]
plts[[10]]
plts[[11]]
plts[[12]]
plts[[13]]
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# This is the collection of codes that read food atlas datasets and CDC health indicator datasets from Github repository, integrate datasets and cleaning data

# %%
#merge food atlas datasets into one
import pandas as pd

dfs=list()
url_folder='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/Food_atlas/'
filenames=['ACCESS','ASSISTANCE','HEALTH','INSECURITY','LOCAL','PRICES_TAXES','RESTAURANTS','SOCIOECONOMIC','STORES']
for i,filename in enumerate(filenames):
    url=url_folder+filename+".csv"   
    d=pd.read_csv(url,index_col='FIPS',encoding="ISO-8859-1")
    #append datasets to the list and drop the redundent columns:'State' and 'County'
    if i!=0:
        dfs.append(d.drop(['State', 'County'], axis=1))
    else:
        dfs.append(d)

#merge datasets
df_merge=pd.concat(dfs, join='outer', axis=1)

# %%
print (df_merge.head(5))
# Out:
#      State   County  LACCESS_POP10  LACCESS_POP15  PCH_LACCESS_POP_10_15  \
# FIPS
# 1001    AL  Autauga   18428.439690   17496.693040              -5.056026
# 1003    AL  Baldwin   35210.814080   30561.264430             -13.204891
# 1005    AL  Barbour    5722.305602    6069.523628               6.067799
# 1007    AL     Bibb    1044.867327     969.378841              -7.224696
# 1009    AL   Blount    1548.175559    3724.428242             140.568857
#
#       PCT_LACCESS_POP10  PCT_LACCESS_POP15  LACCESS_LOWI10  LACCESS_LOWI15  \
# FIPS
# 1001          33.769657          32.062255     5344.427472     6543.676824
# 1003          19.318473          16.767489     9952.144027     9886.831137
# 1005          20.840972          22.105560     3135.676086     2948.790251
# 1007           4.559753           4.230324      491.449066      596.162829
# 1009           2.700840           6.497380      609.027708     1650.959482
#
#       PCH_LACCESS_LOWI_10_15        ...          PCH_SNAPS_12_16  SNAPSPTH12  \
# FIPS                                ...
# 1001               22.439248        ...                30.957684    0.674004
# 1003               -0.656270        ...                58.313251    0.725055
# 1005               -5.959985        ...                11.961722    1.280590
# 1007               21.307144        ...                29.230770    0.719122
# 1009              171.081177        ...                68.421051    0.657144
#
#       SNAPSPTH16  PCH_SNAPSPTH_12_16  WICS08  WICS12  PCH_WICS_08_12  \
# FIPS
# 1001    0.884221           31.189270       6       5       -16.66667
# 1003    1.050042           44.822353      25      27         8.00000
# 1005    1.502022           17.291382       6       7        16.66667
# 1007    0.927439           28.968229       6       5       -16.66667
# 1009    1.109109           68.777138      10       6       -40.00000
#
#       WICSPTH08  WICSPTH12  PCH_WICSPTH_08_12
# FIPS
# 1001   0.119156   0.090067         -24.412460
# 1003   0.141875   0.141517          -0.252126
# 1005   0.201099   0.257344          27.968330
# 1007   0.277919   0.221268         -20.383970
# 1009   0.173028   0.103760         -40.033200
#
# [5 rows x 279 columns]

# %% [markdown]
# Check columns for missing values

# %%
df_merge.describe()
# Out:
#        LACCESS_POP10  LACCESS_POP15  PCH_LACCESS_POP_10_15  PCT_LACCESS_POP10  \
# count    3143.000000    3124.000000           3.117000e+03        3143.000000
# mean    20156.653242   19287.747386           7.180008e+03          23.559330
# std     51308.865791   47803.525595           3.955676e+05          20.250176
# min         0.000000       0.000000          -1.000000e+02           0.000000
# 25%      1661.076793    1631.358727          -1.091343e+01          10.847099
# 50%      4097.827186    4131.174278          -6.239322e-02          19.685956
# 75%     12954.123205   13119.029393           7.262080e+00          29.581054
# max    886068.668400  740267.412700           2.208376e+07         100.000001
#
#        PCT_LACCESS_POP15  LACCESS_LOWI10  LACCESS_LOWI15  \
# count        3124.000000     3143.000000     3123.000000
# mean           23.084470     5551.776559     5833.959524
# std            19.602745    13862.922934    13989.348252
# min             0.000000        0.000000        0.000000
# 25%            10.927326      592.983070      608.235919
# 50%            19.200682     1500.780036     1636.858816
# 75%            28.862231     4591.067541     4859.016156
# max           100.000001   292541.789000   259479.516000
#
#        PCH_LACCESS_LOWI_10_15  PCT_LACCESS_LOWI10  PCT_LACCESS_LOWI15  \
# count            3.115000e+03         3143.000000         3123.000000
# mean             7.318957e+03            8.374953            8.651256
# std              4.004692e+05            8.214988            8.368703
# min             -1.000000e+02            0.000000            0.000000
# 25%             -1.232638e+01            3.442171            3.625438
# 50%              3.486028e+00            6.150772            6.508531
# 75%              2.352342e+01           10.324935           10.679796
# max              2.234893e+07           72.274456           71.844209
#
#              ...          PCH_SNAPS_12_16   SNAPSPTH12   SNAPSPTH16  \
# count        ...              3140.000000  3143.000000  3141.000000
# mean         ...                19.774565     0.880064     1.025253
# std          ...                32.074488     0.387638     0.451670
# min          ...              -100.000000     0.000000     0.000000
# 25%          ...                 5.405406     0.629603     0.750265
# 50%          ...                15.915190     0.818400     0.965336
# 75%          ...                28.979172     1.066786     1.234080
# max          ...              1100.000000     6.658001     6.695621
#
#        PCH_SNAPSPTH_12_16       WICS08       WICS12  PCH_WICS_08_12  \
# count         3138.000000  3143.000000  3143.000000     3124.000000
# mean            20.079051    14.371619    15.109131       -1.901222
# std             39.262939    49.856567    55.831489       25.937208
# min           -100.000000     0.000000     0.000000     -100.000000
# 25%              5.136099     3.000000     3.000000      -12.500000
# 50%             15.206350     5.000000     5.000000        0.000000
# 75%             28.328855    11.000000    11.000000        0.000000
# max           1135.312012  1285.000000  1602.000000      300.000000
#
#          WICSPTH08    WICSPTH12  PCH_WICSPTH_08_12
# count  3143.000000  3143.000000        3124.000000
# mean      0.255593     0.230473          -3.995745
# std       0.257250     0.211762          25.580415
# min       0.000000     0.000000        -100.000000
# 25%       0.123272     0.118920         -15.333640
# 50%       0.189785     0.177336          -2.383872
# 75%       0.296110     0.268129           3.158470
# max       4.618937     2.994012         294.070300
#
# [8 rows x 277 columns]

# %%
number_null_values_percol=df_merge.isnull().sum(axis=0)
#columns with over 100 missing values
cols_with_over_200_percent_null_values=number_null_values_percol[number_null_values_percol>200]
print (cols_with_over_200_percent_null_values.index)
# Out:
# Index(['REDEMP_SNAPS12', 'PCH_REDEMP_SNAPS_12_16', 'PCT_FREE_LUNCH14',
#        'PCT_REDUCED_LUNCH14', 'PC_WIC_REDEMP08', 'PC_WIC_REDEMP12',
#        'PCH_PC_WIC_REDEMP_08_12', 'REDEMP_WICS08', 'REDEMP_WICS12',
#        'PCH_REDEMP_WICS_08_12', 'PCT_HSPA15', 'PCT_LOCLSALE07',
#        'PCT_LOCLSALE12', 'DIRSALES07', 'DIRSALES12', 'PCH_DIRSALES_07_12',
#        'PC_DIRSALES07', 'PC_DIRSALES12', 'PCH_PC_DIRSALES_07_12',
#        'PCH_FMRKT_09_16', 'PCH_FMRKTPTH_09_16', 'FMRKT_SNAP16',
#        'PCT_FMRKT_SNAP16', 'FMRKT_WIC16', 'PCT_FMRKT_WIC16', 'FMRKT_WICCASH16',
#        'PCT_FMRKT_WICCASH16', 'FMRKT_SFMNP16', 'PCT_FMRKT_SFMNP16',
#        'FMRKT_CREDIT16', 'PCT_FMRKT_CREDIT16', 'FMRKT_FRVEG16',
#        'PCT_FMRKT_FRVEG16', 'FMRKT_ANMLPROD16', 'PCT_FMRKT_ANMLPROD16',
#        'FMRKT_BAKED16', 'PCT_FMRKT_BAKED16', 'FMRKT_OTHERFOOD16',
#        'PCT_FMRKT_OTHERFOOD16', 'PCH_VEG_FARMS_07_12', 'VEG_ACRES07',
#        'VEG_ACRES12', 'PCH_VEG_ACRES_07_12', 'VEG_ACRESPTH07',
#        'VEG_ACRESPTH12', 'PCH_VEG_ACRESPTH_07_12', 'PCH_FRESHVEG_FARMS_07_12',
#        'FRESHVEG_ACRES07', 'FRESHVEG_ACRES12', 'PCH_FRESHVEG_ACRES_07_12',
#        'FRESHVEG_ACRESPTH07', 'FRESHVEG_ACRESPTH12',
#        'PCH_FRESHVEG_ACRESPTH_07_12', 'PCH_ORCHARD_FARMS_07_12',
#        'ORCHARD_ACRES07', 'ORCHARD_ACRES12', 'PCH_ORCHARD_ACRES_07_12',
#        'ORCHARD_ACRESPTH07', 'ORCHARD_ACRESPTH12',
#        'PCH_ORCHARD_ACRESPTH_07_12', 'PCH_BERRY_FARMS_07_12', 'BERRY_ACRES07',
#        'BERRY_ACRES12', 'PCH_BERRY_ACRES_07_12', 'BERRY_ACRESPTH07',
#        'BERRY_ACRESPTH12', 'PCH_BERRY_ACRESPTH_07_12', 'PCH_GHVEG_FARMS_07_12',
#        'GHVEG_SQFT07', 'GHVEG_SQFT12', 'PCH_GHVEG_SQFT_07_12',
#        'GHVEG_SQFTPTH07', 'GHVEG_SQFTPTH12', 'PCH_GHVEG_SQFTPTH_07_12',
#        'PCH_CSA_07_12', 'PCH_AGRITRSM_OPS_07_12', 'AGRITRSM_RCT07',
#        'AGRITRSM_RCT12', 'PCH_AGRITRSM_RCT_07_12', 'FARM_TO_SCHOOL13'],
#       dtype='object')

# %%
#drop these columns first
df_merge=df_merge.drop(list(cols_with_over_200_percent_null_values.index), axis=1)

# %%
#check number of remaining columns
print (df_merge.columns)
# Out:
# Index(['State', 'County', 'LACCESS_POP10', 'LACCESS_POP15',
#        'PCH_LACCESS_POP_10_15', 'PCT_LACCESS_POP10', 'PCT_LACCESS_POP15',
#        'LACCESS_LOWI10', 'LACCESS_LOWI15', 'PCH_LACCESS_LOWI_10_15',
#        ...
#        'PCH_SNAPS_12_16', 'SNAPSPTH12', 'SNAPSPTH16', 'PCH_SNAPSPTH_12_16',
#        'WICS08', 'WICS12', 'PCH_WICS_08_12', 'WICSPTH08', 'WICSPTH12',
#        'PCH_WICSPTH_08_12'],
#       dtype='object', length=199)

# %% [markdown]
# categorizes columns into three groups: category data ('State' and 'County'), count data, percent data, # per 1000 pop, and percent change
#
# columns to keep: category data ('State' and 'County'), percent data, # per 1000 pop, and percent change; remove count data because it is not adjusted by population size
#
# Each column name is highly abstract and unreadable, need to extract info from the variable information provided by Food_atlas

# %%
from collections import defaultdict

url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/Food_atlas/variable_info.csv'
var_info_df=pd.read_csv(url,encoding="ISO-8859-1")
var_info_dict=defaultdict(list)
for idx in var_info_df.index:
    k=var_info_df['Units'][idx]
    var_info_dict[k].append(var_info_df['Variable Code'][idx])

# %% [markdown]
# further filter varaibles based on following principles:
# i. keep variables that are adjusted by population size: '% change', 'Percent', '# per 1,000 pop','Percentage points';
# ii. keep variables that are mostly valuable for analysis
# iii. keep variables where values are valid: e.g. no negative values for variables with units as 'Percent' or '# per 1,000 pop'.

# %%
#units to keep: '% change', 'Percent', '# per 1,000 pop','Percentage points'
for k in var_info_dict.keys():
    if k not in ['% change', 'Percent', '# per 1,000 pop','Percentage points', 'Dollars'] and var_info_dict[k] not in ['State','County']:
        df_merge = df_merge[df_merge.columns.difference(var_info_dict[k])]
        
#print (df_merge.shape)

# %%
#view variables
for idx in var_info_df.index:
    k=var_info_df['Units'][idx]
    k1=var_info_df['Category Code'][idx]
    k2=var_info_df['Sub_subcategory Name'][idx]
    var=var_info_df['Variable Code'][idx]
    
    if var in df_merge.columns:
        print (k1,k2,k,var)
# Out:
# ACCESS Overall % change PCH_LACCESS_POP_10_15
# ACCESS Overall Percent PCT_LACCESS_POP10
# ACCESS Overall Percent PCT_LACCESS_POP15
# ACCESS Low income % change PCH_LACCESS_LOWI_10_15
# ACCESS Low income Percent PCT_LACCESS_LOWI10
# ACCESS Low income Percent PCT_LACCESS_LOWI15
# ACCESS no car % change PCH_LACCESS_HHNV_10_15
# ACCESS no car Percent PCT_LACCESS_HHNV10
# ACCESS no car Percent PCT_LACCESS_HHNV15
# ACCESS SNAP Percent PCT_LACCESS_SNAP15
# ACCESS Children Percent PCT_LACCESS_CHILD10
# ACCESS Children Percent PCT_LACCESS_CHILD15
# ACCESS Seniors % change PCH_LACCESS_SENIORS_10_15
# ACCESS Seniors Percent PCT_LACCESS_SENIORS10
# ACCESS Seniors Percent PCT_LACCESS_SENIORS15
# ACCESS White Percent PCT_LACCESS_WHITE15
# ACCESS Black Percent PCT_LACCESS_BLACK15
# ACCESS Hispanic ethnicity Percent PCT_LACCESS_HISP15
# ACCESS Asian Percent PCT_LACCESS_NHASIAN15
# ACCESS American Indian or Alaska Native Percent PCT_LACCESS_NHNA15
# ACCESS Hawaiian or Pacific Islander Percent PCT_LACCESS_NHPI15
# ACCESS Multiracial Percent PCT_LACCESS_MULTIR15
# STORES Grocery % change PCH_GROC_09_14
# STORES Grocery # per 1,000 pop GROCPTH09
# STORES Grocery # per 1,000 pop GROCPTH14
# STORES Supercenters % change PCH_SUPERC_09_14
# STORES Supercenters # per 1,000 pop SUPERCPTH09
# STORES Supercenters # per 1,000 pop SUPERCPTH14
# STORES Supercenters % change PCH_SUPERCPTH_09_14
# STORES Convenience % change PCH_CONVS_09_14
# STORES Convenience # per 1,000 pop CONVSPTH09
# STORES Convenience # per 1,000 pop CONVSPTH14
# STORES Convenience % change PCH_CONVSPTH_09_14
# STORES Specialized % change PCH_SPECS_09_14
# STORES Specialized # per 1,000 pop SPECSPTH09
# STORES Specialized # per 1,000 pop SPECSPTH14
# STORES Specialized % change PCH_SPECSPTH_09_14
# STORES SNAP-authorized % change PCH_SNAPS_12_16
# STORES SNAP-authorized # per 1,000 pop SNAPSPTH12
# STORES SNAP-authorized # per 1,000 pop SNAPSPTH16
# STORES SNAP-authorized % change PCH_SNAPSPTH_12_16
# STORES WIC-authorized % change PCH_WICS_08_12
# STORES WIC-authorized # per 1,000 pop WICSPTH08
# STORES WIC-authorized # per 1,000 pop WICSPTH12
# STORES WIC-authorized % change PCH_WICSPTH_08_12
# RESTAURANTS Fast-food % change PCH_FFR_09_14
# RESTAURANTS Fast-food # per 1,000 pop FFRPTH09
# RESTAURANTS Fast-food # per 1,000 pop FFRPTH14
# RESTAURANTS Fast-food % change PCH_FFRPTH_09_14
# RESTAURANTS Full-service % change PCH_FSR_09_14
# RESTAURANTS Full-service # per 1,000 pop FSRPTH09
# RESTAURANTS Full-service # per 1,000 pop FSRPTH14
# RESTAURANTS fast food Dollars PC_FFRSALES07
# RESTAURANTS fast food Dollars PC_FFRSALES12
# RESTAURANTS restaurants Dollars PC_FSRSALES07
# RESTAURANTS restaurants Dollars PC_FSRSALES12
# ASSISTANCE SNAP participants Percent PCT_SNAP12
# ASSISTANCE SNAP participants  Percent PCT_SNAP16
# ASSISTANCE SNAP participants Percentage points PCH_SNAP_12_16
# ASSISTANCE SNAP benefits per capita % change PCH_PC_SNAPBEN_10_15
# ASSISTANCE SNAP participants/eligible pop Percent SNAP_PART_RATE08
# ASSISTANCE SNAP participants/eligible pop Percent SNAP_PART_RATE13
# ASSISTANCE National School Lunch Program participants  Percent PCT_NSLP09
# ASSISTANCE National School Lunch Program participants  Percent PCT_NSLP15
# ASSISTANCE National School Lunch Program participants  Percentage points PCH_NSLP_09_15
# ASSISTANCE Students eligible for free lunch Percent PCT_FREE_LUNCH09
# ASSISTANCE Students eligible for reduced-price lunch Percent PCT_REDUCED_LUNCH09
# ASSISTANCE School Breakfast Program participants Percent PCT_SBP09
# ASSISTANCE School Breakfast Program participants Percent PCT_SBP15
# ASSISTANCE School Breakfast Program participants Percentage points PCH_SBP_09_15
# ASSISTANCE Summer Food Program participants Percent PCT_SFSP09
# ASSISTANCE Summer Food Program participants Percent PCT_SFSP15
# ASSISTANCE Summer Food Program participants Percentage points PCH_SFSP_09_15
# ASSISTANCE WIC participants Percent PCT_WIC09
# ASSISTANCE WIC participants Percent PCT_WIC15
# ASSISTANCE WIC participants Percentage points PCH_WIC_09_15
# ASSISTANCE nan Percent PCT_CACFP09
# ASSISTANCE nan Percent PCT_CACFP15
# ASSISTANCE nan Percentage points PCH_CACFP_09_15
# INSECURITY Household food insecurity Percent FOODINSEC_10_12
# INSECURITY Household food insecurity Percent FOODINSEC_13_15
# INSECURITY Household food insecurity Percentage points CH_FOODINSEC_12_15
# INSECURITY Household very low food security Percent VLFOODSEC_10_12
# INSECURITY Household very low food security Percent VLFOODSEC_13_15
# INSECURITY Household very low food security Percentage points CH_VLFOODSEC_12_15
# INSECURITY Household child food insecurity Percent FOODINSEC_CHILD_01_07
# INSECURITY Household child food insecurity Percent FOODINSEC_CHILD_03_11
# PRICES_TAXES Soda/retail stores Percent SODATAX_STORES14
# PRICES_TAXES Soda/vending Percent SODATAX_VENDM14
# PRICES_TAXES Chip & pretzel sales tax/ retail stores Percent CHIPSTAX_STORES14
# PRICES_TAXES Chip & pretzel sales tax/ retail stores Percent CHIPSTAX_VENDM14
# PRICES_TAXES General food sales tax/ retail stores Percent FOOD_TAX14
# LOCAL Farms % change PCH_DIRSALES_FARMS_07_12
# LOCAL Farms Percent PCT_LOCLFARM07
# LOCAL Farms Percent PCT_LOCLFARM12
# LOCAL overall # per 1,000 pop FMRKTPTH09
# LOCAL overall # per 1,000 pop FMRKTPTH16
# LOCAL Small slaughterhouse facilities % change PCH_SLHOUSE_07_12
# HEALTH Adult diabetes rate Percent PCT_DIABETES_ADULTS08
# HEALTH Adult diabetes rate Percent PCT_DIABETES_ADULTS13
# HEALTH Adult obesity rate Percent PCT_OBESE_ADULTS08
# HEALTH Adult obesity rate Percent PCT_OBESE_ADULTS13
# HEALTH Recreation & fitness facilities % change PCH_RECFAC_09_14
# HEALTH Recreation & fitness facilities # per 1,000 pop RECFACPTH09
# HEALTH Recreation & fitness facilities # per 1,000 pop RECFACPTH14
# HEALTH Recreation & fitness facilities % change PCH_RECFACPTH_09_14
# SOCIOECONOMIC White Percent PCT_NHWHITE10
# SOCIOECONOMIC Black Percent PCT_NHBLACK10
# SOCIOECONOMIC Hispanic Percent PCT_HISP10
# SOCIOECONOMIC Asian Percent PCT_NHASIAN10
# SOCIOECONOMIC American Indian or Alaska Native Percent PCT_NHNA10
# SOCIOECONOMIC Hawaiian or Pacific Islander Percent PCT_NHPI10
# SOCIOECONOMIC >=65 Percent PCT_65OLDER10
# SOCIOECONOMIC <18 Percent PCT_18YOUNGER10
# SOCIOECONOMIC Median household income Dollars MEDHHINC15
# SOCIOECONOMIC Poverty rate Percent POVRATE15
# SOCIOECONOMIC Child poverty rate Percent CHILDPOVRATE15

# %%
print (df_merge.shape)
# Out:
# (3143, 120)

# %%
df_merge=df_merge[['PCH_LACCESS_POP_10_15','PCT_LACCESS_POP10','PCT_LACCESS_POP15',
                   'PCH_LACCESS_LOWI_10_15','PCT_LACCESS_LOWI10', 'PCT_LACCESS_LOWI15', 
                   'PCT_LACCESS_CHILD10','PCT_LACCESS_CHILD15',
                   'PCH_LACCESS_SENIORS_10_15','PCT_LACCESS_SENIORS10','PCT_LACCESS_SENIORS15',
                   'PCH_GROC_09_14','GROCPTH09','GROCPTH14',
                   'SUPERCPTH09','SUPERCPTH14','PCH_CONVS_09_14', 
                   'CONVSPTH09','CONVSPTH14','PCH_CONVSPTH_09_14', 
                   'SPECSPTH09','SPECSPTH14',
                   'PCH_SNAPS_12_16','SNAPSPTH12','SNAPSPTH16','PCH_SNAPSPTH_12_16',
                   'PCH_WICS_08_12','WICSPTH08','WICSPTH12','PCH_WICSPTH_08_12',
                   'PCH_FFR_09_14','FFRPTH09','FFRPTH14',
                    'PCH_FFRPTH_09_14','PCH_FSR_09_14','FSRPTH09',
                    'FSRPTH14','PCT_CACFP09','PCT_CACFP15','PCH_CACFP_09_15',
                    'FOODINSEC_10_12','FOODINSEC_13_15','CH_FOODINSEC_12_15',
                    'VLFOODSEC_10_12','VLFOODSEC_13_15','CH_VLFOODSEC_12_15',
                    'RECFACPTH09','RECFACPTH14',
                    'PCT_NHWHITE10', 'PCT_NHBLACK10', 'PCT_HISP10','PCT_NHASIAN10',
                    'PCT_NHNA10','PCT_NHPI10','PCT_65OLDER10','PCT_18YOUNGER10','POVRATE15',
                     'PCT_DIABETES_ADULTS08', 'PCT_DIABETES_ADULTS13','PCT_OBESE_ADULTS08','PCT_OBESE_ADULTS13',
                     'FMRKTPTH09', 'FMRKTPTH16','State','County']]

# %%
print(df_merge.shape)
#view variables
for idx in var_info_df.index:
    k=var_info_df['Units'][idx]
    k1=var_info_df['Category Code'][idx]
    k2=var_info_df['Sub_subcategory Name'][idx]
    var=var_info_df['Variable Code'][idx]
    
    if var in df_merge.columns:
        print (k1,k2,k,var)
# Out:
# (3143, 65)
# ACCESS Overall % change PCH_LACCESS_POP_10_15
# ACCESS Overall Percent PCT_LACCESS_POP10
# ACCESS Overall Percent PCT_LACCESS_POP15
# ACCESS Low income % change PCH_LACCESS_LOWI_10_15
# ACCESS Low income Percent PCT_LACCESS_LOWI10
# ACCESS Low income Percent PCT_LACCESS_LOWI15
# ACCESS Children Percent PCT_LACCESS_CHILD10
# ACCESS Children Percent PCT_LACCESS_CHILD15
# ACCESS Seniors % change PCH_LACCESS_SENIORS_10_15
# ACCESS Seniors Percent PCT_LACCESS_SENIORS10
# ACCESS Seniors Percent PCT_LACCESS_SENIORS15
# STORES Grocery % change PCH_GROC_09_14
# STORES Grocery # per 1,000 pop GROCPTH09
# STORES Grocery # per 1,000 pop GROCPTH14
# STORES Supercenters # per 1,000 pop SUPERCPTH09
# STORES Supercenters # per 1,000 pop SUPERCPTH14
# STORES Convenience % change PCH_CONVS_09_14
# STORES Convenience # per 1,000 pop CONVSPTH09
# STORES Convenience # per 1,000 pop CONVSPTH14
# STORES Convenience % change PCH_CONVSPTH_09_14
# STORES Specialized # per 1,000 pop SPECSPTH09
# STORES Specialized # per 1,000 pop SPECSPTH14
# STORES SNAP-authorized % change PCH_SNAPS_12_16
# STORES SNAP-authorized # per 1,000 pop SNAPSPTH12
# STORES SNAP-authorized # per 1,000 pop SNAPSPTH16
# STORES SNAP-authorized % change PCH_SNAPSPTH_12_16
# STORES WIC-authorized % change PCH_WICS_08_12
# STORES WIC-authorized # per 1,000 pop WICSPTH08
# STORES WIC-authorized # per 1,000 pop WICSPTH12
# STORES WIC-authorized % change PCH_WICSPTH_08_12
# RESTAURANTS Fast-food % change PCH_FFR_09_14
# RESTAURANTS Fast-food # per 1,000 pop FFRPTH09
# RESTAURANTS Fast-food # per 1,000 pop FFRPTH14
# RESTAURANTS Fast-food % change PCH_FFRPTH_09_14
# RESTAURANTS Full-service % change PCH_FSR_09_14
# RESTAURANTS Full-service # per 1,000 pop FSRPTH09
# RESTAURANTS Full-service # per 1,000 pop FSRPTH14
# ASSISTANCE nan Percent PCT_CACFP09
# ASSISTANCE nan Percent PCT_CACFP15
# ASSISTANCE nan Percentage points PCH_CACFP_09_15
# INSECURITY Household food insecurity Percent FOODINSEC_10_12
# INSECURITY Household food insecurity Percent FOODINSEC_13_15
# INSECURITY Household food insecurity Percentage points CH_FOODINSEC_12_15
# INSECURITY Household very low food security Percent VLFOODSEC_10_12
# INSECURITY Household very low food security Percent VLFOODSEC_13_15
# INSECURITY Household very low food security Percentage points CH_VLFOODSEC_12_15
# LOCAL overall # per 1,000 pop FMRKTPTH09
# LOCAL overall # per 1,000 pop FMRKTPTH16
# HEALTH Adult diabetes rate Percent PCT_DIABETES_ADULTS08
# HEALTH Adult diabetes rate Percent PCT_DIABETES_ADULTS13
# HEALTH Adult obesity rate Percent PCT_OBESE_ADULTS08
# HEALTH Adult obesity rate Percent PCT_OBESE_ADULTS13
# HEALTH Recreation & fitness facilities # per 1,000 pop RECFACPTH09
# HEALTH Recreation & fitness facilities # per 1,000 pop RECFACPTH14
# SOCIOECONOMIC White Percent PCT_NHWHITE10
# SOCIOECONOMIC Black Percent PCT_NHBLACK10
# SOCIOECONOMIC Hispanic Percent PCT_HISP10
# SOCIOECONOMIC Asian Percent PCT_NHASIAN10
# SOCIOECONOMIC American Indian or Alaska Native Percent PCT_NHNA10
# SOCIOECONOMIC Hawaiian or Pacific Islander Percent PCT_NHPI10
# SOCIOECONOMIC >=65 Percent PCT_65OLDER10
# SOCIOECONOMIC <18 Percent PCT_18YOUNGER10
# SOCIOECONOMIC Poverty rate Percent POVRATE15

# %%
#devide dataframe into two: one with variables measured at one year and one with variables as percent change、
var_timepoint=list()
var_percentchange=list()
for idx in var_info_df.index:
    k=var_info_df['Units'][idx]
    k1=var_info_df['Category Code'][idx]
    k2=var_info_df['Sub_subcategory Name'][idx]
    var=var_info_df['Variable Code'][idx]
    
    if var in df_merge.columns: 
        if k in ['Percent', '# per 1,000 pop']:
            var_timepoint.append(var)
        elif k in ['% change','Percentage points']:
            var_percentchange.append(var)
var_timepoint.extend(['State','County'])
var_percentchange.extend(['State','County'])
df_tp=df_merge[var_timepoint]
df_pr=df_merge[var_percentchange]

# %%
print (df_tp.shape)
print (df_pr.shape)
# Out:
# (3143, 49)
# (3143, 18)
# Index(['PCH_LACCESS_POP_10_15', 'PCH_LACCESS_LOWI_10_15',
#        'PCH_LACCESS_SENIORS_10_15', 'PCH_GROC_09_14', 'PCH_CONVS_09_14',
#        'PCH_CONVSPTH_09_14', 'PCH_SNAPS_12_16', 'PCH_SNAPSPTH_12_16',
#        'PCH_WICS_08_12', 'PCH_WICSPTH_08_12', 'PCH_FFR_09_14',
#        'PCH_FFRPTH_09_14', 'PCH_FSR_09_14', 'PCH_CACFP_09_15',
#        'CH_FOODINSEC_12_15', 'CH_VLFOODSEC_12_15', 'State', 'County'],
#       dtype='object')

# %%
#check weather each column has valid values:
####### columns with units 'Percent' should have values between 0 and 100, any value that fall out of this range should be changed to NaN values
###### 
######
######

#Replace invalid values with np.nan
import numpy as np

for idx in var_info_df.index:
    k=var_info_df['Units'][idx]
    k1=var_info_df['Category Code'][idx]
    k2=var_info_df['Sub_subcategory Name'][idx]
    var=var_info_df['Variable Code'][idx]
    
    if k =='Percent' and var in df_tp.columns: 
        ser=df_tp[var]<0 
        ser=ser+df_tp[var]>100
        if ser.sum()>0:
            print ((k1,k2,var,ser.sum()))
            df_tp[var][(df_tp[var]<0)|(df_tp[var]>100)]=np.nan
    elif k=='# per 1,000 pop' and var in df_tp.columns:
        ser=df_tp[var]<0
        ser=ser+df_tp[var]>1000
        if ser.sum()>0:
            print ((k1,k2,var,ser.sum()))
            df_tp[var][(df_tp[var]<0)|(df_tp[var]>1000)]=np.nan
    elif k=='Percentage points' and var in df_pr.columns:
        ser=df_pr[var]>100
        ser=df_pr[var]<-100
        if ser.sum()>0:
            print ((k1,k2,var,ser.sum())) 
            df_pr[var][(df_pr[var]<-100)|(df_pr[var]>100)]=np.nan
# Out:
# ('ACCESS', 'Overall', 'PCT_LACCESS_POP10', 25)
# ('ACCESS', 'Overall', 'PCT_LACCESS_POP15', 22)
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\anaconda\lib\site-packages\pandas\core\generic.py:5233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2862: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#break df_tp into two sets: variables measured at the earlier time point: df_tp_1; and variables measured at the earlier time point: df_tp_2

#group the same measure into tuples, the same measure share the same name except the last two digits which indicate the year of the measure
var_grouped_by_measures=defaultdict(list)
early_measure_list=['State','County']
late_measure_list=['State','County']
for idx in var_info_df.index:
    k=var_info_df['Units'][idx]
    k1=var_info_df['Category Code'][idx]
    k2=var_info_df['Sub_subcategory Name'][idx]
    var=var_info_df['Variable Code'][idx]
    
    if var in df_tp.columns and var not in ['State','County']:
        var_grouped_by_measures[(k1,k2)].append((var, float(var[-2:])))
    
for v in var_grouped_by_measures.values():
    v.sort(key=lambda tup: tup[-1])
    late_measure_list.append(v[-1][0])

df_tp_later=df_tp[late_measure_list]

# %%
print (df_tp_later.shape)
print (df_pr.shape)
# Out:
# (3143, 30)
# (3143, 18)

# %%
print (df_tp_later.columns)
print (df_pr.columns)
# Out:
# Index(['State', 'County', 'PCT_LACCESS_POP15', 'PCT_LACCESS_LOWI15',
#        'PCT_LACCESS_CHILD15', 'PCT_LACCESS_SENIORS15', 'GROCPTH14',
#        'SUPERCPTH14', 'CONVSPTH14', 'SPECSPTH14', 'SNAPSPTH16', 'WICSPTH12',
#        'FFRPTH14', 'FSRPTH14', 'PCT_CACFP15', 'FOODINSEC_13_15',
#        'VLFOODSEC_13_15', 'FMRKTPTH16', 'PCT_DIABETES_ADULTS13',
#        'PCT_OBESE_ADULTS13', 'RECFACPTH14', 'PCT_NHWHITE10', 'PCT_NHBLACK10',
#        'PCT_HISP10', 'PCT_NHASIAN10', 'PCT_NHNA10', 'PCT_NHPI10',
#        'PCT_65OLDER10', 'PCT_18YOUNGER10', 'POVRATE15'],
#       dtype='object')
# Index(['PCH_LACCESS_POP_10_15', 'PCH_LACCESS_LOWI_10_15',
#        'PCH_LACCESS_SENIORS_10_15', 'PCH_GROC_09_14', 'PCH_CONVS_09_14',
#        'PCH_CONVSPTH_09_14', 'PCH_SNAPS_12_16', 'PCH_SNAPSPTH_12_16',
#        'PCH_WICS_08_12', 'PCH_WICSPTH_08_12', 'PCH_FFR_09_14',
#        'PCH_FFRPTH_09_14', 'PCH_FSR_09_14', 'PCH_CACFP_09_15',
#        'CH_FOODINSEC_12_15', 'CH_VLFOODSEC_12_15', 'State', 'County'],
#       dtype='object')

# %%
#calculate the per year change in each variable
# construct the dictionary of variables information 
var_trans_dict={'LACCESS_POP':'Low_Access_Overall',
                'LACCESS_LOWI':'Low_Access_low_income',
                'LACCESS_CHILD':'Low_Access_Child',
                'LACCESS_SENIORS':'Low_Access_Seniors',
               'GROC':'Grocery',
                'SUPERC':'Supercenter',
                'CONVS':'Convenience',
                'SPECS':'Specialized',
                'SNAPS':'SNAP_store',
                'WICS':'WIC_store',
                 'FFR':'Fast_food',
                 'FSR':'Full_service',
                 'FFRSALES':'Expend_fast_food',
                 'FSRSALES':'Expend_full_service',
                 'CACFP':'Assistance',
                 'FOODINSEC':'Low_insecurity',
                 'VLFOODSEC':'Very_low_insecurity',
                 'RECFAC':'Recreation_facility',
                 'NHWHITE':'White',
                  'NHBLACK':'Black',
                  'HISP':'Hispanic',
                   'NHASIAN1':'Asian',
                   'NHNA':'American Indian or Alaska Native',
                    'NHPI':'Hawaiian or Pacific Islander',
                    '65OLDER':'>=65',
                    '18YOUNGER':'<18',
                    'POVRATE':'Poverty_rate',
                    'DIABETES_ADULT':'Adult_db',
                    'OBESE_ADULTS':'Adult_ob',
                    'FMRKT':'Farm'}

# %%
'''cols=list(df_pr.columns)
new_cols=list()
for c in cols:
    print (c)
    if c in ['State', 'County']:
        new_cols.append(c)
    else:
        for k in var_trans_dict.keys():
            if k in c:
                print (c,k)
                new_cols.append(var_trans_dict[k])
print (new_cols)
df_pr.columns=new_cols'''

          
cols=list(df_tp_later.columns)
new_cols=list()
for c in cols:
    if c in ['State', 'County']:
        new_cols.append(c)
    else:
        for k in var_trans_dict.keys():
            if k in c:
                new_cols.append(var_trans_dict[k])
df_tp_later.columns=new_cols

# %%
print (df_tp_later.head(5))
print (df_pr.head(5))
# Out:
#      State   County  Low_Access_Overall  Low_Access_low_income  \
# FIPS
# 1001    AL  Autauga           32.062255              11.991125
# 1003    AL  Baldwin           16.767489               5.424427
# 1005    AL  Barbour           22.105560              10.739667
# 1007    AL     Bibb            4.230324               2.601627
# 1009    AL   Blount            6.497380               2.880150
#
#       Low_Access_Child  Low_Access_Seniors   Grocery  Supercenter  \
# FIPS
# 1001          8.460485            3.996279  0.072209     0.018052
# 1003          3.844936            3.061840  0.144920     0.029983
# 1005          3.758341            3.001695  0.185963     0.037193
# 1007          1.015242            0.600865  0.222163     0.044433
# 1009          1.588720            0.882583  0.103952     0.017325
#
#       Convenience  Specialized      ...       Recreation_facility      White  \
# FIPS                                ...
# 1001     0.541565     0.036104      ...                  0.090261  77.246156
# 1003     0.589673     0.129928      ...                  0.124931  83.504787
# 1005     0.706661     0.074385      ...                  0.000000  46.753105
# 1007     0.666489     0.044433      ...                  0.044433  75.020729
# 1009     0.467784     0.000000      ...                  0.051976  88.887338
#
#           Black  Hispanic     Asian  American Indian or Alaska Native  \
# FIPS
# 1001  17.582599  2.400542  0.855766                          0.397647
# 1003   9.308425  4.384824  0.735193                          0.628755
# 1005  46.691190  5.051535  0.389700                          0.218524
# 1007  21.924504  1.771765  0.096007                          0.279293
# 1009   1.263040  8.070200  0.200621                          0.497191
#
#       Hawaiian or Pacific Islander       >=65        <18  Poverty_rate
# FIPS
# 1001                      0.040314  11.995382  26.777959          12.7
# 1003                      0.043343  16.771185  22.987408          12.9
# 1005                      0.087409  14.236807  21.906982          32.0
# 1007                      0.030548  12.681650  22.696923          22.2
# 1009                      0.031402  14.722096  24.608353          14.7
#
# [5 rows x 30 columns]
#       Low_Access_Overall  Low_Access_low_income  Low_Access_Seniors  \
# FIPS
# 1001           -5.056026              22.439248           -8.685247
# 1003          -13.204891              -0.656270          -12.856726
# 1005            6.067799              -5.959985            7.005933
# 1007           -7.224696              21.307144           -8.545207
# 1009          140.568857             171.081177          159.377977
#
#         Grocery  Convenience  Convenience  SNAP_store  SNAP_store  WIC_store  \
# FIPS
# 1001 -33.333333     3.448276     1.095269   30.957684   31.189270  -16.66667
# 1003  20.833333    -0.840336   -11.100146   58.313251   44.822353    8.00000
# 1005   0.000000    35.714286    39.600922   11.961722   17.291382   16.66667
# 1007 -16.666667   -21.052632   -19.526723   29.230770   28.968229  -16.66667
# 1009   0.000000   -12.903226   -13.473620   68.421051   68.777138  -40.00000
#
#       WIC_store  Fast_food  Fast_food  Full_service  Assistance  \
# FIPS
# 1001 -24.412460  20.000000  17.270512    -14.705882    0.139507
# 1003  -0.252126  17.857143   5.662750      9.405941    0.139507
# 1005  27.968330   4.761905   7.762116     25.000000    0.139507
# 1007 -20.383970 -28.571429 -27.190844    -16.666667    0.139507
# 1009 -40.033200 -12.500000 -13.073035    -21.052632    0.139507
#
#       Low_insecurity  Very_low_insecurity State   County
# FIPS
# 1001            -0.3                  0.5    AL  Autauga
# 1003            -0.3                  0.5    AL  Baldwin
# 1005            -0.3                  0.5    AL  Barbour
# 1007            -0.3                  0.5    AL     Bibb
# 1009            -0.3                  0.5    AL   Blount

# %%
df_pr.to_csv('C:/Users/cathy/Capstone_Project_1/Datasets/Food_atlas/df_pr.csv')
df_tp_later.to_csv('C:/Users/cathy/Capstone_Project_1/Datasets/Food_atlas/df_tp.csv')

# %% [markdown]
# Integrate CDC Datasets together

# %%
import pandas as pd
dfs=list()
url_folder='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/CDC/'
filenames=['Diabetes_prevalence',
           'Obesity_prevalence',
           'Physical_inactive_prevalence']

# %%
for filename in filenames:
    url=url_folder+filename+".csv"   
    df=pd.read_csv(url,index_col='FIPS',encoding="ISO-8859-1")
    
    
    if 'Diabetes' in filename:
        df.columns=df.columns.astype(str)+'_db'
    elif 'Obesity' in filename:
        df.columns=df.columns.astype(str)+'_ob'
    elif 'Physical' in filename:
        df.columns=df.columns.astype(str)+'_phy'
    dfs.append(df)
#merge datasets

# %%
CDC_merge=pd.concat(dfs, join='outer', axis=1)

# %%
CDC_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3224 entries, 1001 to 72153
# Data columns (total 30 columns):
# 2004_db     3224 non-null object
# 2005_db     3224 non-null object
# 2006_db     3224 non-null object
# 2007_db     3224 non-null object
# 2008_db     3224 non-null object
# 2009_db     3224 non-null object
# 2010_db     3224 non-null object
# 2011_db     3224 non-null object
# 2012_db     3224 non-null object
# 2013_db     3224 non-null object
# 2004_ob     3224 non-null object
# 2005_ob     3224 non-null object
# 2006_ob     3224 non-null object
# 2007_ob     3224 non-null object
# 2008_ob     3224 non-null object
# 2009_ob     3224 non-null object
# 2010_ob     3224 non-null object
# 2011_ob     3146 non-null object
# 2012_ob     3146 non-null object
# 2013_ob     3146 non-null object
# 2004_phy    3224 non-null object
# 2005_phy    3224 non-null object
# 2006_phy    3224 non-null object
# 2007_phy    3224 non-null object
# 2008_phy    3224 non-null object
# 2009_phy    3224 non-null object
# 2010_phy    3224 non-null object
# 2011_phy    3224 non-null object
# 2012_phy    3146 non-null object
# 2013_phy    3146 non-null object
# dtypes: object(30)
# memory usage: 780.8+ KB

# %%
#Find out the non numeric entries in CDC_merge
for c in CDC_merge.columns:
    num_non_numeric=sum(CDC_merge.applymap(lambda x: isinstance(x, (int, float)))[c])
    if num_non_numeric>0:
        print(c, num_non_numeric, CDC_merge[pd.to_numeric(CDC_merge[c], errors='coerce').isnull()])
# Out:
# 2011_ob 78       2004_db             2005_db 2006_db 2007_db 2008_db  2009_db  2010_db  \
# FIPS
# 2201      5.8  6.1000000000000005     5.9     6.8     7.4  No Data  No Data
# 2232      5.8  6.1000000000000005     6.6     6.9     5.2  No Data  No Data
# 2280      5.4                 6.2     6.4       7       7  No Data  No Data
# 72001    11.4                10.9    12.8    12.7    14.3     14.7     15.4
# 72003    12.4                14.9    16.3    15.5    14.7     14.6     16.4
# 72005    12.8                14.6    16.3    14.9    15.4       15     15.9
# 72007    11.1                12.9      14    14.7    14.7     15.1       15
# 72009      13                13.6    13.7    13.2    13.2     12.5     13.9
# 72011    12.1                13.8    15.3    14.9    14.7     14.8     16.9
# 72013    13.8                14.5    14.8    15.3    16.4     17.9     17.2
# 72015    13.6                13.9    13.4    13.8    14.1     14.1     14.2
# 72017    12.7                13.9    13.8    13.5    14.8     16.4     17.4
# 72019    11.9                12.9    12.6      13    13.5     13.8     14.7
# 72021    11.6                  11    11.6    11.3    11.8     12.6     13.9
# 72023    11.6                11.4    12.1    12.3    14.1     15.2     15.7
# 72025    11.3                  13    13.3    14.1    13.3     13.9       13
# 72027    11.5                11.7    13.2    13.4    13.8     13.6     15.6
# 72029    11.4                12.1    11.7    11.9    12.1     13.1     14.8
# 72031    10.9                  12      13    13.7    13.3       14     14.9
# 72033    12.7                12.4    13.1    12.2    13.3     13.5     14.8
# 72035      11                10.8    11.4    11.5    13.3     14.4       15
# 72037      12                12.5    13.9    13.4    12.3     12.5     15.4
# 72039    13.9                14.1    13.9    13.9    15.4     16.1     16.8
# 72041      12                12.1    11.3    10.5    12.4     13.4     13.7
# 72043    11.2                11.4    12.4    12.8    13.3     14.7     14.5
# 72045    12.6                  14    13.5    13.4      14     13.9     15.6
# 72047    12.2                  13    13.6    12.6    13.4     12.9     15.4
# 72049    10.5                10.6      13    13.6      13     14.7     12.7
# 72051    11.5                  12    11.8    13.2      12     12.1     12.9
# 72053    14.7                15.2    15.7    13.6    13.3       14     15.6
# ...       ...                 ...     ...     ...     ...      ...      ...
# 72095    13.6                16.5    15.5    16.5    15.9     16.9     17.6
# 72097    13.2                14.9    16.1    16.8    15.7       16     15.1
# 72099    11.9                12.8    14.2    13.7    13.9     13.8     14.9
# 72101    12.1                13.2    13.3    12.7    13.5     13.6     15.3
# 72103      14                14.4    14.5    13.1    12.9     12.7       15
# 72105    12.6                13.4    13.9    13.7    13.6     12.9     14.7
# 72107    12.9                13.9    14.3    13.8    14.3     14.4     15.4
# 72109    13.9                15.3    15.5    14.6    15.5     16.1     17.8
# 72111    12.8                12.8    12.9      12    14.4     14.5     16.7
# 72113    13.4                13.4    13.8      13    14.3     14.8     15.6
# 72115    13.9                14.4    15.6    16.3    16.9     15.7     17.2
# 72117    12.6                  15    17.5    18.6    17.4       17     18.2
# 72119    12.1                12.2    12.7    12.3    12.8     14.1     14.5
# 72121    12.7                13.5    13.8    14.5    14.8     15.2       15
# 72123    12.2                11.7    12.7    12.1    13.6     14.2     16.1
# 72125    13.9                14.6    15.8    16.3    16.2     16.4     17.5
# 72127    11.3                10.8    11.6    11.7    12.8     12.4     12.5
# 72129    10.7                11.9    12.5    12.9    13.3     14.1     15.1
# 72131    13.8                15.6    15.5    16.5    16.2     16.9     17.9
# 72133    11.2                10.3    11.1    11.2    12.1     13.2     12.6
# 72135     9.5                 9.2     9.5     9.4     9.7      9.9     11.5
# 72137    11.5                11.5    11.9    11.8    11.1     11.9     12.7
# 72139     8.9                   9    10.1    11.5    11.7     12.8     12.2
# 72141    13.5                13.6      14    14.4    15.8     16.6     15.3
# 72143    11.9                12.4    12.7    13.4    13.7     14.2     14.8
# 72145    11.4                12.6      15    15.2    14.5     12.9     14.1
# 72147    11.3                12.2      14    16.4    16.3       17     14.8
# 72149      11                  11      12    11.9    12.3     11.9       14
# 72151    13.1                14.6    14.3    14.2    13.7     14.1     15.6
# 72153    13.7                13.7    13.5      13      14     13.4     15.6
#
#        2011_db  2012_db  2013_db   ...    2004_phy 2005_phy 2006_phy 2007_phy  \
# FIPS                               ...
# 2201   No Data  No Data  No Data   ...        22.7     26.8       29     26.8
# 2232   No Data  No Data  No Data   ...        21.4     22.5       23     25.2
# 2280   No Data  No Data  No Data   ...        18.4     18.9     20.2     23.1
# 72001     18.3     20.7     21.8   ...     No Data  No Data  No Data  No Data
# 72003     16.2     15.3     16.1   ...     No Data  No Data  No Data  No Data
# 72005     15.2     15.1       16   ...     No Data  No Data  No Data  No Data
# 72007     15.3     16.2     16.8   ...     No Data  No Data  No Data  No Data
# 72009       14     14.3     14.9   ...     No Data  No Data  No Data  No Data
# 72011     17.4     17.1     17.9   ...     No Data  No Data  No Data  No Data
# 72013     16.1     15.5     16.7   ...     No Data  No Data  No Data  No Data
# 72015     16.4     18.2     18.9   ...     No Data  No Data  No Data  No Data
# 72017     16.9     17.7     17.5   ...     No Data  No Data  No Data  No Data
# 72019     14.4     14.3     14.4   ...     No Data  No Data  No Data  No Data
# 72021     15.8     15.1     15.2   ...     No Data  No Data  No Data  No Data
# 72023     16.1     15.9     17.7   ...     No Data  No Data  No Data  No Data
# 72025     14.2       14     15.3   ...     No Data  No Data  No Data  No Data
# 72027     15.7     16.4     17.1   ...     No Data  No Data  No Data  No Data
# 72029     15.3     16.3     15.4   ...     No Data  No Data  No Data  No Data
# 72031       16     15.8     16.1   ...     No Data  No Data  No Data  No Data
# 72033     16.5     15.9     15.9   ...     No Data  No Data  No Data  No Data
# 72035     14.4     13.9     14.3   ...     No Data  No Data  No Data  No Data
# 72037       18       18     18.5   ...     No Data  No Data  No Data  No Data
# 72039       16     16.7     17.9   ...     No Data  No Data  No Data  No Data
# 72041     13.6     12.9     13.6   ...     No Data  No Data  No Data  No Data
# 72043     16.5     15.9       18   ...     No Data  No Data  No Data  No Data
# 72045     15.4     15.1     15.5   ...     No Data  No Data  No Data  No Data
# 72047       15     15.4     16.4   ...     No Data  No Data  No Data  No Data
# 72049     17.6     20.4     24.3   ...     No Data  No Data  No Data  No Data
# 72051     15.2     14.7     14.7   ...     No Data  No Data  No Data  No Data
# 72053     17.4     17.9       19   ...     No Data  No Data  No Data  No Data
# ...        ...      ...      ...   ...         ...      ...      ...      ...
# 72095     17.3     17.5     17.8   ...     No Data  No Data  No Data  No Data
# 72097     15.7     15.6     16.8   ...     No Data  No Data  No Data  No Data
# 72099     14.6     15.6     16.9   ...     No Data  No Data  No Data  No Data
# 72101     15.6     15.7     16.5   ...     No Data  No Data  No Data  No Data
# 72103     15.8     17.2     17.4   ...     No Data  No Data  No Data  No Data
# 72105     15.3     15.8       16   ...     No Data  No Data  No Data  No Data
# 72107     14.8     15.1     16.6   ...     No Data  No Data  No Data  No Data
# 72109     18.5     19.4     20.1   ...     No Data  No Data  No Data  No Data
# 72111     16.3     16.6     17.3   ...     No Data  No Data  No Data  No Data
# 72113       16     15.6     16.3   ...     No Data  No Data  No Data  No Data
# 72115     15.8     17.1     17.4   ...     No Data  No Data  No Data  No Data
# 72117     17.3     17.7     17.5   ...     No Data  No Data  No Data  No Data
# 72119     14.9       15     17.2   ...     No Data  No Data  No Data  No Data
# 72121     16.9     17.8     18.6   ...     No Data  No Data  No Data  No Data
# 72123     17.1     18.4     18.6   ...     No Data  No Data  No Data  No Data
# 72125     17.1     16.8     16.6   ...     No Data  No Data  No Data  No Data
# 72127     12.9     13.7     13.9   ...     No Data  No Data  No Data  No Data
# 72129       15     15.1     16.5   ...     No Data  No Data  No Data  No Data
# 72131     18.7     19.5     19.2   ...     No Data  No Data  No Data  No Data
# 72133     14.3     13.4       15   ...     No Data  No Data  No Data  No Data
# 72135     12.9     13.1     13.1   ...     No Data  No Data  No Data  No Data
# 72137       15     14.6     14.4   ...     No Data  No Data  No Data  No Data
# 72139     13.4     12.9     13.7   ...     No Data  No Data  No Data  No Data
# 72141     15.2     15.6     18.1   ...     No Data  No Data  No Data  No Data
# 72143     15.8       16     16.2   ...     No Data  No Data  No Data  No Data
# 72145     15.2     16.7     17.7   ...     No Data  No Data  No Data  No Data
# 72147     18.6     19.2     22.6   ...     No Data  No Data  No Data  No Data
# 72149       15     15.2     16.1   ...     No Data  No Data  No Data  No Data
# 72151     15.5     15.4     16.6   ...     No Data  No Data  No Data  No Data
# 72153     15.5     17.1     17.2   ...     No Data  No Data  No Data  No Data
#
#       2008_phy 2009_phy 2010_phy 2011_phy 2012_phy 2013_phy
# FIPS
# 2201      25.3  No Data  No Data  No Data  No Data  No Data
# 2232      22.1  No Data  No Data  No Data  No Data  No Data
# 2280      24.6  No Data  No Data  No Data  No Data  No Data
# 72001  No Data  No Data  No Data  No Data      NaN      NaN
# 72003  No Data  No Data  No Data  No Data      NaN      NaN
# 72005  No Data  No Data  No Data  No Data      NaN      NaN
# 72007  No Data  No Data  No Data  No Data      NaN      NaN
# 72009  No Data  No Data  No Data  No Data      NaN      NaN
# 72011  No Data  No Data  No Data  No Data      NaN      NaN
# 72013  No Data  No Data  No Data  No Data      NaN      NaN
# 72015  No Data  No Data  No Data  No Data      NaN      NaN
# 72017  No Data  No Data  No Data  No Data      NaN      NaN
# 72019  No Data  No Data  No Data  No Data      NaN      NaN
# 72021  No Data  No Data  No Data  No Data      NaN      NaN
# 72023  No Data  No Data  No Data  No Data      NaN      NaN
# 72025  No Data  No Data  No Data  No Data      NaN      NaN
# 72027  No Data  No Data  No Data  No Data      NaN      NaN
# 72029  No Data  No Data  No Data  No Data      NaN      NaN
# 72031  No Data  No Data  No Data  No Data      NaN      NaN
# 72033  No Data  No Data  No Data  No Data      NaN      NaN
# 72035  No Data  No Data  No Data  No Data      NaN      NaN
# 72037  No Data  No Data  No Data  No Data      NaN      NaN
# 72039  No Data  No Data  No Data  No Data      NaN      NaN
# 72041  No Data  No Data  No Data  No Data      NaN      NaN
# 72043  No Data  No Data  No Data  No Data      NaN      NaN
# 72045  No Data  No Data  No Data  No Data      NaN      NaN
# 72047  No Data  No Data  No Data  No Data      NaN      NaN
# 72049  No Data  No Data  No Data  No Data      NaN      NaN
# 72051  No Data  No Data  No Data  No Data      NaN      NaN
# 72053  No Data  No Data  No Data  No Data      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...
# 72095  No Data  No Data  No Data  No Data      NaN      NaN
# 72097  No Data  No Data  No Data  No Data      NaN      NaN
# 72099  No Data  No Data  No Data  No Data      NaN      NaN
# 72101  No Data  No Data  No Data  No Data      NaN      NaN
# 72103  No Data  No Data  No Data  No Data      NaN      NaN
# 72105  No Data  No Data  No Data  No Data      NaN      NaN
# 72107  No Data  No Data  No Data  No Data      NaN      NaN
# 72109  No Data  No Data  No Data  No Data      NaN      NaN
# 72111  No Data  No Data  No Data  No Data      NaN      NaN
# 72113  No Data  No Data  No Data  No Data      NaN      NaN
# 72115  No Data  No Data  No Data  No Data      NaN      NaN
# 72117  No Data  No Data  No Data  No Data      NaN      NaN
# 72119  No Data  No Data  No Data  No Data      NaN      NaN
# 72121  No Data  No Data  No Data  No Data      NaN      NaN
# 72123  No Data  No Data  No Data  No Data      NaN      NaN
# 72125  No Data  No Data  No Data  No Data      NaN      NaN
# 72127  No Data  No Data  No Data  No Data      NaN      NaN
# 72129  No Data  No Data  No Data  No Data      NaN      NaN
# 72131  No Data  No Data  No Data  No Data      NaN      NaN
# 72133  No Data  No Data  No Data  No Data      NaN      NaN
# 72135  No Data  No Data  No Data  No Data      NaN      NaN
# 72137  No Data  No Data  No Data  No Data      NaN      NaN
# 72139  No Data  No Data  No Data  No Data      NaN      NaN
# 72141  No Data  No Data  No Data  No Data      NaN      NaN
# 72143  No Data  No Data  No Data  No Data      NaN      NaN
# 72145  No Data  No Data  No Data  No Data      NaN      NaN
# 72147  No Data  No Data  No Data  No Data      NaN      NaN
# 72149  No Data  No Data  No Data  No Data      NaN      NaN
# 72151  No Data  No Data  No Data  No Data      NaN      NaN
# 72153  No Data  No Data  No Data  No Data      NaN      NaN
#
# [81 rows x 30 columns]
# 2012_ob 78       2004_db             2005_db 2006_db 2007_db 2008_db  2009_db  2010_db  \
# FIPS
# 2201      5.8  6.1000000000000005     5.9     6.8     7.4  No Data  No Data
# 2232      5.8  6.1000000000000005     6.6     6.9     5.2  No Data  No Data
# 2280      5.4                 6.2     6.4       7       7  No Data  No Data
# 72001    11.4                10.9    12.8    12.7    14.3     14.7     15.4
# 72003    12.4                14.9    16.3    15.5    14.7     14.6     16.4
# 72005    12.8                14.6    16.3    14.9    15.4       15     15.9
# 72007    11.1                12.9      14    14.7    14.7     15.1       15
# 72009      13                13.6    13.7    13.2    13.2     12.5     13.9
# 72011    12.1                13.8    15.3    14.9    14.7     14.8     16.9
# 72013    13.8                14.5    14.8    15.3    16.4     17.9     17.2
# 72015    13.6                13.9    13.4    13.8    14.1     14.1     14.2
# 72017    12.7                13.9    13.8    13.5    14.8     16.4     17.4
# 72019    11.9                12.9    12.6      13    13.5     13.8     14.7
# 72021    11.6                  11    11.6    11.3    11.8     12.6     13.9
# 72023    11.6                11.4    12.1    12.3    14.1     15.2     15.7
# 72025    11.3                  13    13.3    14.1    13.3     13.9       13
# 72027    11.5                11.7    13.2    13.4    13.8     13.6     15.6
# 72029    11.4                12.1    11.7    11.9    12.1     13.1     14.8
# 72031    10.9                  12      13    13.7    13.3       14     14.9
# 72033    12.7                12.4    13.1    12.2    13.3     13.5     14.8
# 72035      11                10.8    11.4    11.5    13.3     14.4       15
# 72037      12                12.5    13.9    13.4    12.3     12.5     15.4
# 72039    13.9                14.1    13.9    13.9    15.4     16.1     16.8
# 72041      12                12.1    11.3    10.5    12.4     13.4     13.7
# 72043    11.2                11.4    12.4    12.8    13.3     14.7     14.5
# 72045    12.6                  14    13.5    13.4      14     13.9     15.6
# 72047    12.2                  13    13.6    12.6    13.4     12.9     15.4
# 72049    10.5                10.6      13    13.6      13     14.7     12.7
# 72051    11.5                  12    11.8    13.2      12     12.1     12.9
# 72053    14.7                15.2    15.7    13.6    13.3       14     15.6
# ...       ...                 ...     ...     ...     ...      ...      ...
# 72095    13.6                16.5    15.5    16.5    15.9     16.9     17.6
# 72097    13.2                14.9    16.1    16.8    15.7       16     15.1
# 72099    11.9                12.8    14.2    13.7    13.9     13.8     14.9
# 72101    12.1                13.2    13.3    12.7    13.5     13.6     15.3
# 72103      14                14.4    14.5    13.1    12.9     12.7       15
# 72105    12.6                13.4    13.9    13.7    13.6     12.9     14.7
# 72107    12.9                13.9    14.3    13.8    14.3     14.4     15.4
# 72109    13.9                15.3    15.5    14.6    15.5     16.1     17.8
# 72111    12.8                12.8    12.9      12    14.4     14.5     16.7
# 72113    13.4                13.4    13.8      13    14.3     14.8     15.6
# 72115    13.9                14.4    15.6    16.3    16.9     15.7     17.2
# 72117    12.6                  15    17.5    18.6    17.4       17     18.2
# 72119    12.1                12.2    12.7    12.3    12.8     14.1     14.5
# 72121    12.7                13.5    13.8    14.5    14.8     15.2       15
# 72123    12.2                11.7    12.7    12.1    13.6     14.2     16.1
# 72125    13.9                14.6    15.8    16.3    16.2     16.4     17.5
# 72127    11.3                10.8    11.6    11.7    12.8     12.4     12.5
# 72129    10.7                11.9    12.5    12.9    13.3     14.1     15.1
# 72131    13.8                15.6    15.5    16.5    16.2     16.9     17.9
# 72133    11.2                10.3    11.1    11.2    12.1     13.2     12.6
# 72135     9.5                 9.2     9.5     9.4     9.7      9.9     11.5
# 72137    11.5                11.5    11.9    11.8    11.1     11.9     12.7
# 72139     8.9                   9    10.1    11.5    11.7     12.8     12.2
# 72141    13.5                13.6      14    14.4    15.8     16.6     15.3
# 72143    11.9                12.4    12.7    13.4    13.7     14.2     14.8
# 72145    11.4                12.6      15    15.2    14.5     12.9     14.1
# 72147    11.3                12.2      14    16.4    16.3       17     14.8
# 72149      11                  11      12    11.9    12.3     11.9       14
# 72151    13.1                14.6    14.3    14.2    13.7     14.1     15.6
# 72153    13.7                13.7    13.5      13      14     13.4     15.6
#
#        2011_db  2012_db  2013_db   ...    2004_phy 2005_phy 2006_phy 2007_phy  \
# FIPS                               ...
# 2201   No Data  No Data  No Data   ...        22.7     26.8       29     26.8
# 2232   No Data  No Data  No Data   ...        21.4     22.5       23     25.2
# 2280   No Data  No Data  No Data   ...        18.4     18.9     20.2     23.1
# 72001     18.3     20.7     21.8   ...     No Data  No Data  No Data  No Data
# 72003     16.2     15.3     16.1   ...     No Data  No Data  No Data  No Data
# 72005     15.2     15.1       16   ...     No Data  No Data  No Data  No Data
# 72007     15.3     16.2     16.8   ...     No Data  No Data  No Data  No Data
# 72009       14     14.3     14.9   ...     No Data  No Data  No Data  No Data
# 72011     17.4     17.1     17.9   ...     No Data  No Data  No Data  No Data
# 72013     16.1     15.5     16.7   ...     No Data  No Data  No Data  No Data
# 72015     16.4     18.2     18.9   ...     No Data  No Data  No Data  No Data
# 72017     16.9     17.7     17.5   ...     No Data  No Data  No Data  No Data
# 72019     14.4     14.3     14.4   ...     No Data  No Data  No Data  No Data
# 72021     15.8     15.1     15.2   ...     No Data  No Data  No Data  No Data
# 72023     16.1     15.9     17.7   ...     No Data  No Data  No Data  No Data
# 72025     14.2       14     15.3   ...     No Data  No Data  No Data  No Data
# 72027     15.7     16.4     17.1   ...     No Data  No Data  No Data  No Data
# 72029     15.3     16.3     15.4   ...     No Data  No Data  No Data  No Data
# 72031       16     15.8     16.1   ...     No Data  No Data  No Data  No Data
# 72033     16.5     15.9     15.9   ...     No Data  No Data  No Data  No Data
# 72035     14.4     13.9     14.3   ...     No Data  No Data  No Data  No Data
# 72037       18       18     18.5   ...     No Data  No Data  No Data  No Data
# 72039       16     16.7     17.9   ...     No Data  No Data  No Data  No Data
# 72041     13.6     12.9     13.6   ...     No Data  No Data  No Data  No Data
# 72043     16.5     15.9       18   ...     No Data  No Data  No Data  No Data
# 72045     15.4     15.1     15.5   ...     No Data  No Data  No Data  No Data
# 72047       15     15.4     16.4   ...     No Data  No Data  No Data  No Data
# 72049     17.6     20.4     24.3   ...     No Data  No Data  No Data  No Data
# 72051     15.2     14.7     14.7   ...     No Data  No Data  No Data  No Data
# 72053     17.4     17.9       19   ...     No Data  No Data  No Data  No Data
# ...        ...      ...      ...   ...         ...      ...      ...      ...
# 72095     17.3     17.5     17.8   ...     No Data  No Data  No Data  No Data
# 72097     15.7     15.6     16.8   ...     No Data  No Data  No Data  No Data
# 72099     14.6     15.6     16.9   ...     No Data  No Data  No Data  No Data
# 72101     15.6     15.7     16.5   ...     No Data  No Data  No Data  No Data
# 72103     15.8     17.2     17.4   ...     No Data  No Data  No Data  No Data
# 72105     15.3     15.8       16   ...     No Data  No Data  No Data  No Data
# 72107     14.8     15.1     16.6   ...     No Data  No Data  No Data  No Data
# 72109     18.5     19.4     20.1   ...     No Data  No Data  No Data  No Data
# 72111     16.3     16.6     17.3   ...     No Data  No Data  No Data  No Data
# 72113       16     15.6     16.3   ...     No Data  No Data  No Data  No Data
# 72115     15.8     17.1     17.4   ...     No Data  No Data  No Data  No Data
# 72117     17.3     17.7     17.5   ...     No Data  No Data  No Data  No Data
# 72119     14.9       15     17.2   ...     No Data  No Data  No Data  No Data
# 72121     16.9     17.8     18.6   ...     No Data  No Data  No Data  No Data
# 72123     17.1     18.4     18.6   ...     No Data  No Data  No Data  No Data
# 72125     17.1     16.8     16.6   ...     No Data  No Data  No Data  No Data
# 72127     12.9     13.7     13.9   ...     No Data  No Data  No Data  No Data
# 72129       15     15.1     16.5   ...     No Data  No Data  No Data  No Data
# 72131     18.7     19.5     19.2   ...     No Data  No Data  No Data  No Data
# 72133     14.3     13.4       15   ...     No Data  No Data  No Data  No Data
# 72135     12.9     13.1     13.1   ...     No Data  No Data  No Data  No Data
# 72137       15     14.6     14.4   ...     No Data  No Data  No Data  No Data
# 72139     13.4     12.9     13.7   ...     No Data  No Data  No Data  No Data
# 72141     15.2     15.6     18.1   ...     No Data  No Data  No Data  No Data
# 72143     15.8       16     16.2   ...     No Data  No Data  No Data  No Data
# 72145     15.2     16.7     17.7   ...     No Data  No Data  No Data  No Data
# 72147     18.6     19.2     22.6   ...     No Data  No Data  No Data  No Data
# 72149       15     15.2     16.1   ...     No Data  No Data  No Data  No Data
# 72151     15.5     15.4     16.6   ...     No Data  No Data  No Data  No Data
# 72153     15.5     17.1     17.2   ...     No Data  No Data  No Data  No Data
#
#       2008_phy 2009_phy 2010_phy 2011_phy 2012_phy 2013_phy
# FIPS
# 2201      25.3  No Data  No Data  No Data  No Data  No Data
# 2232      22.1  No Data  No Data  No Data  No Data  No Data
# 2280      24.6  No Data  No Data  No Data  No Data  No Data
# 72001  No Data  No Data  No Data  No Data      NaN      NaN
# 72003  No Data  No Data  No Data  No Data      NaN      NaN
# 72005  No Data  No Data  No Data  No Data      NaN      NaN
# 72007  No Data  No Data  No Data  No Data      NaN      NaN
# 72009  No Data  No Data  No Data  No Data      NaN      NaN
# 72011  No Data  No Data  No Data  No Data      NaN      NaN
# 72013  No Data  No Data  No Data  No Data      NaN      NaN
# 72015  No Data  No Data  No Data  No Data      NaN      NaN
# 72017  No Data  No Data  No Data  No Data      NaN      NaN
# 72019  No Data  No Data  No Data  No Data      NaN      NaN
# 72021  No Data  No Data  No Data  No Data      NaN      NaN
# 72023  No Data  No Data  No Data  No Data      NaN      NaN
# 72025  No Data  No Data  No Data  No Data      NaN      NaN
# 72027  No Data  No Data  No Data  No Data      NaN      NaN
# 72029  No Data  No Data  No Data  No Data      NaN      NaN
# 72031  No Data  No Data  No Data  No Data      NaN      NaN
# 72033  No Data  No Data  No Data  No Data      NaN      NaN
# 72035  No Data  No Data  No Data  No Data      NaN      NaN
# 72037  No Data  No Data  No Data  No Data      NaN      NaN
# 72039  No Data  No Data  No Data  No Data      NaN      NaN
# 72041  No Data  No Data  No Data  No Data      NaN      NaN
# 72043  No Data  No Data  No Data  No Data      NaN      NaN
# 72045  No Data  No Data  No Data  No Data      NaN      NaN
# 72047  No Data  No Data  No Data  No Data      NaN      NaN
# 72049  No Data  No Data  No Data  No Data      NaN      NaN
# 72051  No Data  No Data  No Data  No Data      NaN      NaN
# 72053  No Data  No Data  No Data  No Data      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...
# 72095  No Data  No Data  No Data  No Data      NaN      NaN
# 72097  No Data  No Data  No Data  No Data      NaN      NaN
# 72099  No Data  No Data  No Data  No Data      NaN      NaN
# 72101  No Data  No Data  No Data  No Data      NaN      NaN
# 72103  No Data  No Data  No Data  No Data      NaN      NaN
# 72105  No Data  No Data  No Data  No Data      NaN      NaN
# 72107  No Data  No Data  No Data  No Data      NaN      NaN
# 72109  No Data  No Data  No Data  No Data      NaN      NaN
# 72111  No Data  No Data  No Data  No Data      NaN      NaN
# 72113  No Data  No Data  No Data  No Data      NaN      NaN
# 72115  No Data  No Data  No Data  No Data      NaN      NaN
# 72117  No Data  No Data  No Data  No Data      NaN      NaN
# 72119  No Data  No Data  No Data  No Data      NaN      NaN
# 72121  No Data  No Data  No Data  No Data      NaN      NaN
# 72123  No Data  No Data  No Data  No Data      NaN      NaN
# 72125  No Data  No Data  No Data  No Data      NaN      NaN
# 72127  No Data  No Data  No Data  No Data      NaN      NaN
# 72129  No Data  No Data  No Data  No Data      NaN      NaN
# 72131  No Data  No Data  No Data  No Data      NaN      NaN
# 72133  No Data  No Data  No Data  No Data      NaN      NaN
# 72135  No Data  No Data  No Data  No Data      NaN      NaN
# 72137  No Data  No Data  No Data  No Data      NaN      NaN
# 72139  No Data  No Data  No Data  No Data      NaN      NaN
# 72141  No Data  No Data  No Data  No Data      NaN      NaN
# 72143  No Data  No Data  No Data  No Data      NaN      NaN
# 72145  No Data  No Data  No Data  No Data      NaN      NaN
# 72147  No Data  No Data  No Data  No Data      NaN      NaN
# 72149  No Data  No Data  No Data  No Data      NaN      NaN
# 72151  No Data  No Data  No Data  No Data      NaN      NaN
# 72153  No Data  No Data  No Data  No Data      NaN      NaN
#
# [81 rows x 30 columns]
# 2013_ob 78                  2004_db             2005_db 2006_db 2007_db 2008_db  2009_db  \
# FIPS
# 2201                 5.8  6.1000000000000005     5.9     6.8     7.4  No Data
# 2232                 5.8  6.1000000000000005     6.6     6.9     5.2  No Data
# 2280                 5.4                 6.2     6.4       7       7  No Data
# 51515  9.700000000000001  10.200000000000001    11.1    12.1    12.6     12.7
# 72001               11.4                10.9    12.8    12.7    14.3     14.7
# 72003               12.4                14.9    16.3    15.5    14.7     14.6
# 72005               12.8                14.6    16.3    14.9    15.4       15
# 72007               11.1                12.9      14    14.7    14.7     15.1
# 72009                 13                13.6    13.7    13.2    13.2     12.5
# 72011               12.1                13.8    15.3    14.9    14.7     14.8
# 72013               13.8                14.5    14.8    15.3    16.4     17.9
# 72015               13.6                13.9    13.4    13.8    14.1     14.1
# 72017               12.7                13.9    13.8    13.5    14.8     16.4
# 72019               11.9                12.9    12.6      13    13.5     13.8
# 72021               11.6                  11    11.6    11.3    11.8     12.6
# 72023               11.6                11.4    12.1    12.3    14.1     15.2
# 72025               11.3                  13    13.3    14.1    13.3     13.9
# 72027               11.5                11.7    13.2    13.4    13.8     13.6
# 72029               11.4                12.1    11.7    11.9    12.1     13.1
# 72031               10.9                  12      13    13.7    13.3       14
# 72033               12.7                12.4    13.1    12.2    13.3     13.5
# 72035                 11                10.8    11.4    11.5    13.3     14.4
# 72037                 12                12.5    13.9    13.4    12.3     12.5
# 72039               13.9                14.1    13.9    13.9    15.4     16.1
# 72041                 12                12.1    11.3    10.5    12.4     13.4
# 72043               11.2                11.4    12.4    12.8    13.3     14.7
# 72045               12.6                  14    13.5    13.4      14     13.9
# 72047               12.2                  13    13.6    12.6    13.4     12.9
# 72049               10.5                10.6      13    13.6      13     14.7
# 72051               11.5                  12    11.8    13.2      12     12.1
# ...                  ...                 ...     ...     ...     ...      ...
# 72095               13.6                16.5    15.5    16.5    15.9     16.9
# 72097               13.2                14.9    16.1    16.8    15.7       16
# 72099               11.9                12.8    14.2    13.7    13.9     13.8
# 72101               12.1                13.2    13.3    12.7    13.5     13.6
# 72103                 14                14.4    14.5    13.1    12.9     12.7
# 72105               12.6                13.4    13.9    13.7    13.6     12.9
# 72107               12.9                13.9    14.3    13.8    14.3     14.4
# 72109               13.9                15.3    15.5    14.6    15.5     16.1
# 72111               12.8                12.8    12.9      12    14.4     14.5
# 72113               13.4                13.4    13.8      13    14.3     14.8
# 72115               13.9                14.4    15.6    16.3    16.9     15.7
# 72117               12.6                  15    17.5    18.6    17.4       17
# 72119               12.1                12.2    12.7    12.3    12.8     14.1
# 72121               12.7                13.5    13.8    14.5    14.8     15.2
# 72123               12.2                11.7    12.7    12.1    13.6     14.2
# 72125               13.9                14.6    15.8    16.3    16.2     16.4
# 72127               11.3                10.8    11.6    11.7    12.8     12.4
# 72129               10.7                11.9    12.5    12.9    13.3     14.1
# 72131               13.8                15.6    15.5    16.5    16.2     16.9
# 72133               11.2                10.3    11.1    11.2    12.1     13.2
# 72135                9.5                 9.2     9.5     9.4     9.7      9.9
# 72137               11.5                11.5    11.9    11.8    11.1     11.9
# 72139                8.9                   9    10.1    11.5    11.7     12.8
# 72141               13.5                13.6      14    14.4    15.8     16.6
# 72143               11.9                12.4    12.7    13.4    13.7     14.2
# 72145               11.4                12.6      15    15.2    14.5     12.9
# 72147               11.3                12.2      14    16.4    16.3       17
# 72149                 11                  11      12    11.9    12.3     11.9
# 72151               13.1                14.6    14.3    14.2    13.7     14.1
# 72153               13.7                13.7    13.5      13      14     13.4
#
#        2010_db  2011_db  2012_db  2013_db   ...    2004_phy 2005_phy 2006_phy  \
# FIPS                                        ...
# 2201   No Data  No Data  No Data  No Data   ...        22.7     26.8       29
# 2232   No Data  No Data  No Data  No Data   ...        21.4     22.5       23
# 2280   No Data  No Data  No Data  No Data   ...        18.4     18.9     20.2
# 51515     12.8     13.3     12.4  No Data   ...        25.6     25.7     26.5
# 72001     15.4     18.3     20.7     21.8   ...     No Data  No Data  No Data
# 72003     16.4     16.2     15.3     16.1   ...     No Data  No Data  No Data
# 72005     15.9     15.2     15.1       16   ...     No Data  No Data  No Data
# 72007       15     15.3     16.2     16.8   ...     No Data  No Data  No Data
# 72009     13.9       14     14.3     14.9   ...     No Data  No Data  No Data
# 72011     16.9     17.4     17.1     17.9   ...     No Data  No Data  No Data
# 72013     17.2     16.1     15.5     16.7   ...     No Data  No Data  No Data
# 72015     14.2     16.4     18.2     18.9   ...     No Data  No Data  No Data
# 72017     17.4     16.9     17.7     17.5   ...     No Data  No Data  No Data
# 72019     14.7     14.4     14.3     14.4   ...     No Data  No Data  No Data
# 72021     13.9     15.8     15.1     15.2   ...     No Data  No Data  No Data
# 72023     15.7     16.1     15.9     17.7   ...     No Data  No Data  No Data
# 72025       13     14.2       14     15.3   ...     No Data  No Data  No Data
# 72027     15.6     15.7     16.4     17.1   ...     No Data  No Data  No Data
# 72029     14.8     15.3     16.3     15.4   ...     No Data  No Data  No Data
# 72031     14.9       16     15.8     16.1   ...     No Data  No Data  No Data
# 72033     14.8     16.5     15.9     15.9   ...     No Data  No Data  No Data
# 72035       15     14.4     13.9     14.3   ...     No Data  No Data  No Data
# 72037     15.4       18       18     18.5   ...     No Data  No Data  No Data
# 72039     16.8       16     16.7     17.9   ...     No Data  No Data  No Data
# 72041     13.7     13.6     12.9     13.6   ...     No Data  No Data  No Data
# 72043     14.5     16.5     15.9       18   ...     No Data  No Data  No Data
# 72045     15.6     15.4     15.1     15.5   ...     No Data  No Data  No Data
# 72047     15.4       15     15.4     16.4   ...     No Data  No Data  No Data
# 72049     12.7     17.6     20.4     24.3   ...     No Data  No Data  No Data
# 72051     12.9     15.2     14.7     14.7   ...     No Data  No Data  No Data
# ...        ...      ...      ...      ...   ...         ...      ...      ...
# 72095     17.6     17.3     17.5     17.8   ...     No Data  No Data  No Data
# 72097     15.1     15.7     15.6     16.8   ...     No Data  No Data  No Data
# 72099     14.9     14.6     15.6     16.9   ...     No Data  No Data  No Data
# 72101     15.3     15.6     15.7     16.5   ...     No Data  No Data  No Data
# 72103       15     15.8     17.2     17.4   ...     No Data  No Data  No Data
# 72105     14.7     15.3     15.8       16   ...     No Data  No Data  No Data
# 72107     15.4     14.8     15.1     16.6   ...     No Data  No Data  No Data
# 72109     17.8     18.5     19.4     20.1   ...     No Data  No Data  No Data
# 72111     16.7     16.3     16.6     17.3   ...     No Data  No Data  No Data
# 72113     15.6       16     15.6     16.3   ...     No Data  No Data  No Data
# 72115     17.2     15.8     17.1     17.4   ...     No Data  No Data  No Data
# 72117     18.2     17.3     17.7     17.5   ...     No Data  No Data  No Data
# 72119     14.5     14.9       15     17.2   ...     No Data  No Data  No Data
# 72121       15     16.9     17.8     18.6   ...     No Data  No Data  No Data
# 72123     16.1     17.1     18.4     18.6   ...     No Data  No Data  No Data
# 72125     17.5     17.1     16.8     16.6   ...     No Data  No Data  No Data
# 72127     12.5     12.9     13.7     13.9   ...     No Data  No Data  No Data
# 72129     15.1       15     15.1     16.5   ...     No Data  No Data  No Data
# 72131     17.9     18.7     19.5     19.2   ...     No Data  No Data  No Data
# 72133     12.6     14.3     13.4       15   ...     No Data  No Data  No Data
# 72135     11.5     12.9     13.1     13.1   ...     No Data  No Data  No Data
# 72137     12.7       15     14.6     14.4   ...     No Data  No Data  No Data
# 72139     12.2     13.4     12.9     13.7   ...     No Data  No Data  No Data
# 72141     15.3     15.2     15.6     18.1   ...     No Data  No Data  No Data
# 72143     14.8     15.8       16     16.2   ...     No Data  No Data  No Data
# 72145     14.1     15.2     16.7     17.7   ...     No Data  No Data  No Data
# 72147     14.8     18.6     19.2     22.6   ...     No Data  No Data  No Data
# 72149       14       15     15.2     16.1   ...     No Data  No Data  No Data
# 72151     15.6     15.5     15.4     16.6   ...     No Data  No Data  No Data
# 72153     15.6     15.5     17.1     17.2   ...     No Data  No Data  No Data
#
#       2007_phy 2008_phy 2009_phy 2010_phy 2011_phy 2012_phy 2013_phy
# FIPS
# 2201      26.8     25.3  No Data  No Data  No Data  No Data  No Data
# 2232      25.2     22.1  No Data  No Data  No Data  No Data  No Data
# 2280      23.1     24.6  No Data  No Data  No Data  No Data  No Data
# 51515     26.6     27.2     25.8     24.9     25.8     25.1  No Data
# 72001  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72003  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72005  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72007  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72009  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72011  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72013  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72015  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72017  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72019  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72021  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72023  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72025  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72027  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72029  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72031  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72033  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72035  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72037  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72039  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72041  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72043  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72045  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72047  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72049  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72051  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...
# 72095  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72097  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72099  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72101  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72103  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72105  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72107  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72109  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72111  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72113  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72115  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72117  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72119  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72121  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72123  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72125  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72127  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72129  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72131  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72133  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72135  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72137  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72139  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72141  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72143  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72145  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72147  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72149  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72151  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72153  No Data  No Data  No Data  No Data  No Data      NaN      NaN
#
# [82 rows x 30 columns]
# 2012_phy 78       2004_db             2005_db 2006_db 2007_db 2008_db  2009_db  2010_db  \
# FIPS
# 2201      5.8  6.1000000000000005     5.9     6.8     7.4  No Data  No Data
# 2232      5.8  6.1000000000000005     6.6     6.9     5.2  No Data  No Data
# 2280      5.4                 6.2     6.4       7       7  No Data  No Data
# 72001    11.4                10.9    12.8    12.7    14.3     14.7     15.4
# 72003    12.4                14.9    16.3    15.5    14.7     14.6     16.4
# 72005    12.8                14.6    16.3    14.9    15.4       15     15.9
# 72007    11.1                12.9      14    14.7    14.7     15.1       15
# 72009      13                13.6    13.7    13.2    13.2     12.5     13.9
# 72011    12.1                13.8    15.3    14.9    14.7     14.8     16.9
# 72013    13.8                14.5    14.8    15.3    16.4     17.9     17.2
# 72015    13.6                13.9    13.4    13.8    14.1     14.1     14.2
# 72017    12.7                13.9    13.8    13.5    14.8     16.4     17.4
# 72019    11.9                12.9    12.6      13    13.5     13.8     14.7
# 72021    11.6                  11    11.6    11.3    11.8     12.6     13.9
# 72023    11.6                11.4    12.1    12.3    14.1     15.2     15.7
# 72025    11.3                  13    13.3    14.1    13.3     13.9       13
# 72027    11.5                11.7    13.2    13.4    13.8     13.6     15.6
# 72029    11.4                12.1    11.7    11.9    12.1     13.1     14.8
# 72031    10.9                  12      13    13.7    13.3       14     14.9
# 72033    12.7                12.4    13.1    12.2    13.3     13.5     14.8
# 72035      11                10.8    11.4    11.5    13.3     14.4       15
# 72037      12                12.5    13.9    13.4    12.3     12.5     15.4
# 72039    13.9                14.1    13.9    13.9    15.4     16.1     16.8
# 72041      12                12.1    11.3    10.5    12.4     13.4     13.7
# 72043    11.2                11.4    12.4    12.8    13.3     14.7     14.5
# 72045    12.6                  14    13.5    13.4      14     13.9     15.6
# 72047    12.2                  13    13.6    12.6    13.4     12.9     15.4
# 72049    10.5                10.6      13    13.6      13     14.7     12.7
# 72051    11.5                  12    11.8    13.2      12     12.1     12.9
# 72053    14.7                15.2    15.7    13.6    13.3       14     15.6
# ...       ...                 ...     ...     ...     ...      ...      ...
# 72095    13.6                16.5    15.5    16.5    15.9     16.9     17.6
# 72097    13.2                14.9    16.1    16.8    15.7       16     15.1
# 72099    11.9                12.8    14.2    13.7    13.9     13.8     14.9
# 72101    12.1                13.2    13.3    12.7    13.5     13.6     15.3
# 72103      14                14.4    14.5    13.1    12.9     12.7       15
# 72105    12.6                13.4    13.9    13.7    13.6     12.9     14.7
# 72107    12.9                13.9    14.3    13.8    14.3     14.4     15.4
# 72109    13.9                15.3    15.5    14.6    15.5     16.1     17.8
# 72111    12.8                12.8    12.9      12    14.4     14.5     16.7
# 72113    13.4                13.4    13.8      13    14.3     14.8     15.6
# 72115    13.9                14.4    15.6    16.3    16.9     15.7     17.2
# 72117    12.6                  15    17.5    18.6    17.4       17     18.2
# 72119    12.1                12.2    12.7    12.3    12.8     14.1     14.5
# 72121    12.7                13.5    13.8    14.5    14.8     15.2       15
# 72123    12.2                11.7    12.7    12.1    13.6     14.2     16.1
# 72125    13.9                14.6    15.8    16.3    16.2     16.4     17.5
# 72127    11.3                10.8    11.6    11.7    12.8     12.4     12.5
# 72129    10.7                11.9    12.5    12.9    13.3     14.1     15.1
# 72131    13.8                15.6    15.5    16.5    16.2     16.9     17.9
# 72133    11.2                10.3    11.1    11.2    12.1     13.2     12.6
# 72135     9.5                 9.2     9.5     9.4     9.7      9.9     11.5
# 72137    11.5                11.5    11.9    11.8    11.1     11.9     12.7
# 72139     8.9                   9    10.1    11.5    11.7     12.8     12.2
# 72141    13.5                13.6      14    14.4    15.8     16.6     15.3
# 72143    11.9                12.4    12.7    13.4    13.7     14.2     14.8
# 72145    11.4                12.6      15    15.2    14.5     12.9     14.1
# 72147    11.3                12.2      14    16.4    16.3       17     14.8
# 72149      11                  11      12    11.9    12.3     11.9       14
# 72151    13.1                14.6    14.3    14.2    13.7     14.1     15.6
# 72153    13.7                13.7    13.5      13      14     13.4     15.6
#
#        2011_db  2012_db  2013_db   ...    2004_phy 2005_phy 2006_phy 2007_phy  \
# FIPS                               ...
# 2201   No Data  No Data  No Data   ...        22.7     26.8       29     26.8
# ...
# 72115  No Data  No Data  No Data  No Data      NaN      NaN
# 72117  No Data  No Data  No Data  No Data      NaN      NaN
# 72119  No Data  No Data  No Data  No Data      NaN      NaN
# 72121  No Data  No Data  No Data  No Data      NaN      NaN
# 72123  No Data  No Data  No Data  No Data      NaN      NaN
# 72125  No Data  No Data  No Data  No Data      NaN      NaN
# 72127  No Data  No Data  No Data  No Data      NaN      NaN
# 72129  No Data  No Data  No Data  No Data      NaN      NaN
# 72131  No Data  No Data  No Data  No Data      NaN      NaN
# 72133  No Data  No Data  No Data  No Data      NaN      NaN
# 72135  No Data  No Data  No Data  No Data      NaN      NaN
# 72137  No Data  No Data  No Data  No Data      NaN      NaN
# 72139  No Data  No Data  No Data  No Data      NaN      NaN
# 72141  No Data  No Data  No Data  No Data      NaN      NaN
# 72143  No Data  No Data  No Data  No Data      NaN      NaN
# 72145  No Data  No Data  No Data  No Data      NaN      NaN
# 72147  No Data  No Data  No Data  No Data      NaN      NaN
# 72149  No Data  No Data  No Data  No Data      NaN      NaN
# 72151  No Data  No Data  No Data  No Data      NaN      NaN
# 72153  No Data  No Data  No Data  No Data      NaN      NaN
#
# [81 rows x 30 columns]
# 2013_phy 78                  2004_db             2005_db 2006_db 2007_db 2008_db  2009_db  \
# FIPS
# 2201                 5.8  6.1000000000000005     5.9     6.8     7.4  No Data
# 2232                 5.8  6.1000000000000005     6.6     6.9     5.2  No Data
# 2280                 5.4                 6.2     6.4       7       7  No Data
# 51515  9.700000000000001  10.200000000000001    11.1    12.1    12.6     12.7
# 72001               11.4                10.9    12.8    12.7    14.3     14.7
# 72003               12.4                14.9    16.3    15.5    14.7     14.6
# 72005               12.8                14.6    16.3    14.9    15.4       15
# 72007               11.1                12.9      14    14.7    14.7     15.1
# 72009                 13                13.6    13.7    13.2    13.2     12.5
# 72011               12.1                13.8    15.3    14.9    14.7     14.8
# 72013               13.8                14.5    14.8    15.3    16.4     17.9
# 72015               13.6                13.9    13.4    13.8    14.1     14.1
# 72017               12.7                13.9    13.8    13.5    14.8     16.4
# 72019               11.9                12.9    12.6      13    13.5     13.8
# 72021               11.6                  11    11.6    11.3    11.8     12.6
# 72023               11.6                11.4    12.1    12.3    14.1     15.2
# 72025               11.3                  13    13.3    14.1    13.3     13.9
# 72027               11.5                11.7    13.2    13.4    13.8     13.6
# 72029               11.4                12.1    11.7    11.9    12.1     13.1
# 72031               10.9                  12      13    13.7    13.3       14
# 72033               12.7                12.4    13.1    12.2    13.3     13.5
# 72035                 11                10.8    11.4    11.5    13.3     14.4
# 72037                 12                12.5    13.9    13.4    12.3     12.5
# 72039               13.9                14.1    13.9    13.9    15.4     16.1
# 72041                 12                12.1    11.3    10.5    12.4     13.4
# 72043               11.2                11.4    12.4    12.8    13.3     14.7
# 72045               12.6                  14    13.5    13.4      14     13.9
# 72047               12.2                  13    13.6    12.6    13.4     12.9
# 72049               10.5                10.6      13    13.6      13     14.7
# 72051               11.5                  12    11.8    13.2      12     12.1
# ...                  ...                 ...     ...     ...     ...      ...
# 72095               13.6                16.5    15.5    16.5    15.9     16.9
# 72097               13.2                14.9    16.1    16.8    15.7       16
# 72099               11.9                12.8    14.2    13.7    13.9     13.8
# 72101               12.1                13.2    13.3    12.7    13.5     13.6
# 72103                 14                14.4    14.5    13.1    12.9     12.7
# 72105               12.6                13.4    13.9    13.7    13.6     12.9
# 72107               12.9                13.9    14.3    13.8    14.3     14.4
# 72109               13.9                15.3    15.5    14.6    15.5     16.1
# 72111               12.8                12.8    12.9      12    14.4     14.5
# 72113               13.4                13.4    13.8      13    14.3     14.8
# 72115               13.9                14.4    15.6    16.3    16.9     15.7
# 72117               12.6                  15    17.5    18.6    17.4       17
# 72119               12.1                12.2    12.7    12.3    12.8     14.1
# 72121               12.7                13.5    13.8    14.5    14.8     15.2
# 72123               12.2                11.7    12.7    12.1    13.6     14.2
# 72125               13.9                14.6    15.8    16.3    16.2     16.4
# 72127               11.3                10.8    11.6    11.7    12.8     12.4
# 72129               10.7                11.9    12.5    12.9    13.3     14.1
# 72131               13.8                15.6    15.5    16.5    16.2     16.9
# 72133               11.2                10.3    11.1    11.2    12.1     13.2
# 72135                9.5                 9.2     9.5     9.4     9.7      9.9
# 72137               11.5                11.5    11.9    11.8    11.1     11.9
# 72139                8.9                   9    10.1    11.5    11.7     12.8
# 72141               13.5                13.6      14    14.4    15.8     16.6
# 72143               11.9                12.4    12.7    13.4    13.7     14.2
# 72145               11.4                12.6      15    15.2    14.5     12.9
# 72147               11.3                12.2      14    16.4    16.3       17
# 72149                 11                  11      12    11.9    12.3     11.9
# 72151               13.1                14.6    14.3    14.2    13.7     14.1
# 72153               13.7                13.7    13.5      13      14     13.4
#
#        2010_db  2011_db  2012_db  2013_db   ...    2004_phy 2005_phy 2006_phy  \
# FIPS                                        ...
# 2201   No Data  No Data  No Data  No Data   ...        22.7     26.8       29
# 2232   No Data  No Data  No Data  No Data   ...        21.4     22.5       23
# 2280   No Data  No Data  No Data  No Data   ...        18.4     18.9     20.2
# 51515     12.8     13.3     12.4  No Data   ...        25.6     25.7     26.5
# 72001     15.4     18.3     20.7     21.8   ...     No Data  No Data  No Data
# 72003     16.4     16.2     15.3     16.1   ...     No Data  No Data  No Data
# 72005     15.9     15.2     15.1       16   ...     No Data  No Data  No Data
# 72007       15     15.3     16.2     16.8   ...     No Data  No Data  No Data
# 72009     13.9       14     14.3     14.9   ...     No Data  No Data  No Data
# 72011     16.9     17.4     17.1     17.9   ...     No Data  No Data  No Data
# 72013     17.2     16.1     15.5     16.7   ...     No Data  No Data  No Data
# 72015     14.2     16.4     18.2     18.9   ...     No Data  No Data  No Data
# 72017     17.4     16.9     17.7     17.5   ...     No Data  No Data  No Data
# 72019     14.7     14.4     14.3     14.4   ...     No Data  No Data  No Data
# 72021     13.9     15.8     15.1     15.2   ...     No Data  No Data  No Data
# 72023     15.7     16.1     15.9     17.7   ...     No Data  No Data  No Data
# 72025       13     14.2       14     15.3   ...     No Data  No Data  No Data
# 72027     15.6     15.7     16.4     17.1   ...     No Data  No Data  No Data
# 72029     14.8     15.3     16.3     15.4   ...     No Data  No Data  No Data
# 72031     14.9       16     15.8     16.1   ...     No Data  No Data  No Data
# 72033     14.8     16.5     15.9     15.9   ...     No Data  No Data  No Data
# 72035       15     14.4     13.9     14.3   ...     No Data  No Data  No Data
# 72037     15.4       18       18     18.5   ...     No Data  No Data  No Data
# 72039     16.8       16     16.7     17.9   ...     No Data  No Data  No Data
# 72041     13.7     13.6     12.9     13.6   ...     No Data  No Data  No Data
# 72043     14.5     16.5     15.9       18   ...     No Data  No Data  No Data
# 72045     15.6     15.4     15.1     15.5   ...     No Data  No Data  No Data
# 72047     15.4       15     15.4     16.4   ...     No Data  No Data  No Data
# 72049     12.7     17.6     20.4     24.3   ...     No Data  No Data  No Data
# 72051     12.9     15.2     14.7     14.7   ...     No Data  No Data  No Data
# ...        ...      ...      ...      ...   ...         ...      ...      ...
# 72095     17.6     17.3     17.5     17.8   ...     No Data  No Data  No Data
# 72097     15.1     15.7     15.6     16.8   ...     No Data  No Data  No Data
# 72099     14.9     14.6     15.6     16.9   ...     No Data  No Data  No Data
# 72101     15.3     15.6     15.7     16.5   ...     No Data  No Data  No Data
# 72103       15     15.8     17.2     17.4   ...     No Data  No Data  No Data
# 72105     14.7     15.3     15.8       16   ...     No Data  No Data  No Data
# 72107     15.4     14.8     15.1     16.6   ...     No Data  No Data  No Data
# 72109     17.8     18.5     19.4     20.1   ...     No Data  No Data  No Data
# 72111     16.7     16.3     16.6     17.3   ...     No Data  No Data  No Data
# 72113     15.6       16     15.6     16.3   ...     No Data  No Data  No Data
# 72115     17.2     15.8     17.1     17.4   ...     No Data  No Data  No Data
# 72117     18.2     17.3     17.7     17.5   ...     No Data  No Data  No Data
# 72119     14.5     14.9       15     17.2   ...     No Data  No Data  No Data
# 72121       15     16.9     17.8     18.6   ...     No Data  No Data  No Data
# 72123     16.1     17.1     18.4     18.6   ...     No Data  No Data  No Data
# 72125     17.5     17.1     16.8     16.6   ...     No Data  No Data  No Data
# 72127     12.5     12.9     13.7     13.9   ...     No Data  No Data  No Data
# 72129     15.1       15     15.1     16.5   ...     No Data  No Data  No Data
# 72131     17.9     18.7     19.5     19.2   ...     No Data  No Data  No Data
# 72133     12.6     14.3     13.4       15   ...     No Data  No Data  No Data
# 72135     11.5     12.9     13.1     13.1   ...     No Data  No Data  No Data
# 72137     12.7       15     14.6     14.4   ...     No Data  No Data  No Data
# 72139     12.2     13.4     12.9     13.7   ...     No Data  No Data  No Data
# 72141     15.3     15.2     15.6     18.1   ...     No Data  No Data  No Data
# 72143     14.8     15.8       16     16.2   ...     No Data  No Data  No Data
# 72145     14.1     15.2     16.7     17.7   ...     No Data  No Data  No Data
# 72147     14.8     18.6     19.2     22.6   ...     No Data  No Data  No Data
# 72149       14       15     15.2     16.1   ...     No Data  No Data  No Data
# 72151     15.6     15.5     15.4     16.6   ...     No Data  No Data  No Data
# 72153     15.6     15.5     17.1     17.2   ...     No Data  No Data  No Data
#
#       2007_phy 2008_phy 2009_phy 2010_phy 2011_phy 2012_phy 2013_phy
# FIPS
# 2201      26.8     25.3  No Data  No Data  No Data  No Data  No Data
# 2232      25.2     22.1  No Data  No Data  No Data  No Data  No Data
# 2280      23.1     24.6  No Data  No Data  No Data  No Data  No Data
# 51515     26.6     27.2     25.8     24.9     25.8     25.1  No Data
# 72001  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72003  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72005  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72007  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72009  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72011  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72013  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72015  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72017  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72019  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72021  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72023  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72025  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72027  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72029  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72031  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72033  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72035  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72037  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72039  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72041  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72043  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72045  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72047  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72049  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72051  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...
# 72095  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72097  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72099  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72101  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72103  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72105  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72107  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72109  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72111  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72113  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72115  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72117  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72119  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72121  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72123  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72125  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72127  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72129  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72131  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72133  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72135  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72137  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72139  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72141  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72143  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72145  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72147  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72149  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72151  No Data  No Data  No Data  No Data  No Data      NaN      NaN
# 72153  No Data  No Data  No Data  No Data  No Data      NaN      NaN
#
# [82 rows x 30 columns]

# %%
#It turns out that some entries are 'No Data' or NaN, so I replace the 'No Data' with NaN values
CDC_merge=CDC_merge.replace('No Data', np.nan)
CDC_merge=CDC_merge.astype(float)

# %%
#now check the CDC_merge
CDC_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3224 entries, 1001 to 72153
# Data columns (total 30 columns):
# 2004_db     3219 non-null float64
# 2005_db     3219 non-null float64
# 2006_db     3219 non-null float64
# 2007_db     3219 non-null float64
# 2008_db     3219 non-null float64
# 2009_db     3221 non-null float64
# 2010_db     3221 non-null float64
# 2011_db     3221 non-null float64
# 2012_db     3221 non-null float64
# 2013_db     3220 non-null float64
# 2004_ob     3141 non-null float64
# 2005_ob     3141 non-null float64
# 2006_ob     3141 non-null float64
# 2007_ob     3141 non-null float64
# 2008_ob     3141 non-null float64
# 2009_ob     3143 non-null float64
# 2010_ob     3143 non-null float64
# 2011_ob     3143 non-null float64
# 2012_ob     3143 non-null float64
# 2013_ob     3142 non-null float64
# 2004_phy    3141 non-null float64
# 2005_phy    3141 non-null float64
# 2006_phy    3141 non-null float64
# 2007_phy    3141 non-null float64
# 2008_phy    3141 non-null float64
# 2009_phy    3143 non-null float64
# 2010_phy    3143 non-null float64
# 2011_phy    3143 non-null float64
# 2012_phy    3143 non-null float64
# 2013_phy    3142 non-null float64
# dtypes: float64(30)
# memory usage: 940.8 KB

# %%
#choose the latest prevalence of diabetes, obesity and physical inactivity to merge with df_tp 
combined=pd.concat([df_tp_later, CDC_merge[['2013_db','2013_ob','2013_phy']]], join='inner',axis=1)

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3143 entries, 1001 to 56045
# Data columns (total 33 columns):
# State                               3143 non-null object
# County                              3143 non-null object
# Low_Access_Overall                  3102 non-null float64
# Low_Access_low_income               3123 non-null float64
# Low_Access_Child                    3124 non-null float64
# Low_Access_Seniors                  3124 non-null float64
# Grocery                             3143 non-null float64
# Supercenter                         3143 non-null float64
# Convenience                         3143 non-null float64
# Specialized                         3143 non-null float64
# SNAP_store                          3141 non-null float64
# WIC_store                           3143 non-null float64
# Fast_food                           3143 non-null float64
# Full_service                        3143 non-null float64
# Assistance                          3143 non-null float64
# Low_insecurity                      3143 non-null float64
# Very_low_insecurity                 3143 non-null float64
# Farm                                3143 non-null float64
# Adult_db                            3142 non-null float64
# Adult_ob                            3142 non-null float64
# Recreation_facility                 3143 non-null float64
# White                               3143 non-null float64
# Black                               3143 non-null float64
# Hispanic                            3143 non-null float64
# Asian                               3143 non-null float64
# American Indian or Alaska Native    3143 non-null float64
# Hawaiian or Pacific Islander        3143 non-null float64
# >=65                                3143 non-null float64
# <18                                 3143 non-null float64
# Poverty_rate                        3139 non-null float64
# 2013_db                             3142 non-null float64
# 2013_ob                             3142 non-null float64
# 2013_phy                            3142 non-null float64
# dtypes: float64(31), object(2)
# memory usage: 834.9+ KB

# %%
#save to file
combined.to_csv('~/Capstone_Project_1/Datasets/Combined_data.csv')

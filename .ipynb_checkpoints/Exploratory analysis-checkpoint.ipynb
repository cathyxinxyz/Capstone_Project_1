# %% [markdown]
# This is the collection of codes that explore the food atlas datasets and CDC datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
##define functions

#functions to draw boxplot by a category: State, age group, socioeconomics, or their combinations
#df: dataframe to read in, col:the col category by which the data is grouped, vert: direction of boxplot, 0 for horizontal and 1 for vertical
def Boxplot_by_state(df, col, vert):
    col_values=list(set(df[col]))
    col_values.sort()
    for c in df.columns:
        if c !=col:
            boxes=list()
            plt.figure(figsize=(18, 16))       
            for v in col_values:
                df_one_type=df[df[cpl]==s]
                boxes.append(list(df_one_type[c]))
            plt.boxplot(boxes,vert=vert)

            plt.yticks(range(1,len(col_values)+1), col_values)
            plt.title(c)    
            plt.show()

#construct variable info dictionary for analysis purpose
from collections import defaultdict

url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/Food_atlas/variable_info.csv'
var_info_df=pd.read_csv(url,encoding="ISO-8859-1")
var_info_dict=dict()

for idx in var_info_df.index:
    
    k1=var_info_df['Category Code'][idx]
    k2=var_info_df['Sub_subcategory Name'][idx]
    k3=var_info_df['Units'][idx]
    var=var_info_df['Variable Code'][idx]
    
    var_info_dict[var]=[k1,k2,k3]   

#create a subset of dataframe by category
def Df_subset(df, category,var_info_dict):
    vars_to_drop=[]
    for c in df_food.columns:
        if c not in ['State','County']:
            if var_info_dict[c][0] !=category:
                vars_to_drop.append(c)

    df_sub=df.drop(vars_to_drop, axis=1)
    return df_sub

# %% [markdown]
# Read food atlas dataset and CDC datasets and merge these two datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt

food_atlas_url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/Food_atlas/df_tp_1.csv'
cdc_diabetes_url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/CDC/Diabetes_prevalence.csv'
cdc_obesity_url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/CDC/Obesity_prevalence.csv'
cdc_phy_url='https://raw.githubusercontent.com/cathyxinxyz/Capstone_Project_1/master/Datasets/CDC/Physical_inactive_prevalence.csv'

df_food=pd.read_csv(food_atlas_url,index_col='FIPS',encoding="ISO-8859-1")
df_db=pd.read_csv(cdc_diabetes_url,index_col='FIPS',encoding="ISO-8859-1")
df_ob=pd.read_csv(cdc_obesity_url,index_col='FIPS',encoding="ISO-8859-1")
df_phy=pd.read_csv(cdc_phy_url,index_col='FIPS',encoding="ISO-8859-1")

# %%
#break df_food into eight categories for analysis

df_access=Df_subset(df_food, 'ACCESS',var_info_dict)
df_assist=Df_subset(df_food, 'ASSISTANCE',var_info_dict)  
df_rest=Df_subset(df_food, 'RESTAURANTS',var_info_dict)  
df_se=Df_subset(df_food,'SOCIOECONOMIC',var_info_dict)
df_sto=Df_subset(df_food,'STORES',var_info_dict)
df_ins=Df_subset(df_food,'INSECURITY',var_info_dict)
df_loc=Df_subset(df_food,'LOCAL',var_info_dict)
df_rec=Df_subset(df_food,'HEALTH',var_info_dict)

# %%
df_access.describe()
# Out:
#        PCT_LACCESS_POP10  PCT_LACCESS_LOWI10  PCT_LACCESS_HHNV10  \
# count        3118.000000         3143.000000         3143.000000
# mean           22.946432            8.374953            3.154496
# std            19.134196            8.214988            3.207105
# min             0.000000            0.000000            0.000000
# 25%            10.723482            3.442171            1.609832
# 50%            19.567871            6.150772            2.572299
# 75%            29.254677           10.324935            3.806324
# max           100.000000           72.274456           68.470405
#
#        PCT_LACCESS_SNAP15  PCT_LACCESS_CHILD10  PCT_LACCESS_SENIORS10  \
# count         3123.000000          3143.000000            3143.000000
# mean             2.917896             5.505321               3.915474
# std              3.160642             4.880426               4.215192
# min              0.000000             0.000000               0.000000
# 25%              1.132022             2.396962               1.585764
# 50%              2.128783             4.444210               2.827295
# 75%              3.668171             6.964972               4.521918
# max             37.254488            34.015595              29.208633
#
#        PCT_LACCESS_WHITE15  PCT_LACCESS_BLACK15  PCT_LACCESS_HISP15  \
# count          3124.000000          3124.000000         3124.000000
# mean             18.976973             1.879652            2.021269
# std              17.529867             4.139239            5.030497
# min               0.000000             0.000000            0.000000
# 25%               8.518008             0.056762            0.197446
# 50%              15.185443             0.257221            0.579669
# 75%              23.658599             1.682592            1.673132
# max              99.163179            50.136324           79.323968
#
#        PCT_LACCESS_NHASIAN15  PCT_LACCESS_NHNA15  PCT_LACCESS_NHPI15  \
# count            3124.000000         3124.000000         3124.000000
# mean                0.249350            0.804746            0.019207
# std                 0.693856            4.835109            0.134887
# min                 0.000000            0.000000            0.000000
# 25%                 0.027088            0.026997            0.000000
# 50%                 0.085588            0.072033            0.003242
# 75%                 0.249311            0.186646            0.013054
# max                25.087551           83.844210            4.469546
#
#        PCT_LACCESS_MULTIR15
# count           3124.000000
# mean               1.154542
# std                1.864479
# min                0.000000
# 25%                0.221558
# 50%                0.572597
# 75%                1.318699
# max               27.120652

# %%
for c in df_access.columns:
    if c not in ['State', 'County']:
        plt.figure()
        plt.title(var_info_dict[c][0]+'\n'+var_info_dict[c][1]+'\n'+var_info_dict[c][2])
        df_access[c].hist(bins=50)
plt.legend()
plt.show()

# %%
df_assist.describe()
# Out:
#         PCT_SNAP12   PCT_SNAP16    PCT_WIC09  PCT_CACFP09
# count  3143.000000  3143.000000  3143.000000  3143.000000
# mean     15.148961    13.339445     2.958524     1.222476
# std       3.604832     3.196074     0.746310     0.396835
# min       5.866367     5.817753     1.386256     0.387918
# 25%      12.566062    10.961725     2.507607     0.954012
# 50%      15.223027    13.527693     2.731320     1.224745
# 75%      18.353499    15.466672     3.286145     1.424865
# max      22.131516    22.763699     5.078872     2.552547

# %%
for c in df_assist.columns:
    if c not in ['State', 'County']:
        plt.figure()
        plt.title(str(var_info_dict[c][0])+'\n'+str(var_info_dict[c][1])+'\n'+str(var_info_dict[c][2]))
        df_assist[c].hist(bins=50)
plt.legend()
plt.show()

# %%
df_rest.describe()
# Out:
#           FFRPTH09     FSRPTH09
# count  3143.000000  3143.000000
# mean      0.561422     0.774440
# std       0.300987     0.584530
# min       0.000000     0.000000
# 25%       0.403243     0.493836
# 50%       0.565323     0.667858
# 75%       0.703764     0.897423
# max       6.088280    13.698630

# %%
for c in df_resrt.columns:
    if c not in ['State', 'County']:
        plt.figure()
        plt.title(str(var_info_dict[c][0])+'\n'+str(var_info_dict[c][1])+'\n'+str(var_info_dict[c][2]))
        df_rest[c].hist(bins=50)
plt.legend()
plt.show()

# %%
df_se.describe()
# Out:
#        PCT_NHWHITE10  PCT_NHBLACK10   PCT_HISP10  PCT_NHASIAN10   PCT_NHNA10  \
# count    3143.000000    3143.000000  3143.000000    3143.000000  3143.000000
# mean       78.294698       8.748643     8.283674       1.136731     1.871411
# std        19.888149      14.421441    13.190860       2.469841     7.606763
# min         2.667918       0.000000     0.000000       0.000000     0.000000
# 25%        66.917367       0.398882     1.593821       0.269818     0.194950
# 50%        85.763450       1.905529     3.283237       0.463388     0.305003
# 75%        94.168544       9.732428     8.211819       0.985868     0.626658
# max        99.163180      85.438778    95.744774      43.014686    94.945703
#
#         PCT_NHPI10  PCT_65OLDER10  PCT_18YOUNGER10    POVRATE15  \
# count  3143.000000    3143.000000      3143.000000  3139.000000
# mean      0.080453      15.882540        23.419345    16.260975
# std       0.945576       4.190210         3.375268     6.442319
# min       0.000000       3.470599         0.000000     3.400000
# 25%       0.009995      13.122703        21.429605    11.500000
# 50%       0.022916      15.568674        23.327538    15.200000
# 75%       0.046468      18.204279        25.102898    19.700000
# max      48.888889      43.384714        41.573938    47.400000
#
#        CHILDPOVRATE15
# count     3139.000000
# mean        23.238738
# std          9.364172
# min          3.300000
# 25%         16.250000
# 50%         22.300000
# 75%         29.100000
# max         61.600000

# %%
for c in df_se.columns:
    if c not in ['State', 'County']:
        plt.figure()
        plt.title(str(var_info_dict[c][0])+'\n'+str(var_info_dict[c][1])+'\n'+str(var_info_dict[c][2]))
        df_se[c].hist(bins=50)
plt.legend()
plt.show()

# %%
df_sto.describe()
# Out:
#          GROCPTH09  SUPERCPTH09   CONVSPTH09   SPECSPTH09   SNAPSPTH12  \
# count  3143.000000  3143.000000  3143.000000  3143.000000  3143.000000
# mean      0.268142     0.015581     0.600116     0.056792     0.880064
# std       0.227271     0.020936     0.309923     0.075752     0.387638
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.149711     0.000000     0.406012     0.000000     0.629603
# 50%       0.206697     0.007298     0.550178     0.043577     0.818400
# 75%       0.305616     0.025621     0.727262     0.083710     1.066786
# max       3.073770     0.256213     3.121748     1.366120     6.658001
#
#          WICSPTH08
# count  3143.000000
# mean      0.255593
# std       0.257250
# min       0.000000
# 25%       0.123272
# 50%       0.189785
# 75%       0.296110
# max       4.618937

# %%
for c in df_sto.columns:
    if c not in ['State', 'County']:
        plt.figure()
        plt.title(str(var_info_dict[c][0])+'\n'+str(var_info_dict[c][1])+'\n'+str(var_info_dict[c][2]))
        df_sto[c].hist(bins=50)
plt.legend()
plt.show()

# %%
for c in df_ins.columns:
    if c not in ['State', 'County']:
        plt.figure()
        plt.title(str(var_info_dict[c][0])+'\n'+str(var_info_dict[c][1])+'\n'+str(var_info_dict[c][2]))
        df_ins[c].hist(bins=50)
plt.legend()
plt.show()

# %%
df_loc.describe()
# Out:
#         FMRKTPTH09
# count  3137.000000
# mean      0.035973
# std       0.070193
# min       0.000000
# 25%       0.000000
# 50%       0.010234
# 75%       0.043991
# max       1.019888

# %%
for c in df_loc.columns:
    if c not in ['State', 'County']:       
        df_loc[c].hist(bins=50)
        plt.title(str(var_info_dict[c][0])+'\n'+str(var_info_dict[c][1])+'\n'+str(var_info_dict[c][2]))
plt.legend()
plt.show()

# %%
df_rec.describe()
# Out:
#        RECFACPTH09
# count  3143.000000
# mean      0.077687
# std       0.078917
# min       0.000000
# 25%       0.000000
# 50%       0.070302
# 75%       0.112864
# max       0.990099

# %%
for c in df_rec.columns:
    if c not in ['State', 'County']:       
        df_rec[c].hist(bins=50)
        plt.title(str(var_info_dict[c][0])+'\n'+str(var_info_dict[c][1])+'\n'+str(var_info_dict[c][2]))
plt.legend()
plt.show()

# %%
df_db.describe()
# Out:
#         2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# count   3224  3224  3224  3224  3224  3224  3224  3224  3224  3224
# unique   122   127   130   133   132   141   145   152   157   164
# top      7.9   8.6     9   9.4   9.5  11.1   9.7  11.3  11.2   9.5
# freq      99   104    91    84    84    69    72    65    64    61

# %%
for c in df_db.columns:
    print(c, sum(df_phy.applymap(lambda x: isinstance(x, (int, float)))[c]))
# Out:
# 2004 0
# 2005 0
# 2006 0
# 2007 0
# 2008 0
# 2009 0
# 2010 0
# 2011 0
# 2012 78
# 2013 78

# %%
df_db=df_db.replace('No Data', np.nan)

# %%
df_db=df_db.astype(float)

# %%
for c in df_db.columns:
    if c not in ['State', 'County']:       
        df_db[c].hist(bins=50)
        plt.title('Diabetes prevalence, year '+c)
        plt.figure()
plt.legend()
plt.show()

# %%
df_ob.describe()
# Out:
#            2004     2005     2006     2007     2008     2009     2010  2011  \
# count      3224     3224     3224     3224     3224     3224     3224  3146
# unique      220     1185      243      241      245      259      260   265
# top     No Data  No Data  No Data  No Data  No Data  No Data  No Data  30.6
# freq         83       83       83       83       83       81       81    44
#
#         2012  2013
# count   3146  3146
# unique   267   267
# top     31.5  32.6
# freq      43    41

# %%
df_ob=df_ob.replace('No Data', np.nan)
df_ob=df_ob.astype(float)

# %%
for c in df_ob.columns:
    if c not in ['State', 'County']:       
        df_ob[c].hist(bins=50)
        plt.title('Obesity prevalence, year '+c)
        plt.figure()
plt.legend()
plt.show()

# %%
df_phy.describe()
# Out:
#            2004     2005     2006     2007     2008     2009     2010  \
# count      3224     3224     3224     3224     3224     3224     3224
# unique      281      272      288      280      275      275      285
# top     No Data  No Data  No Data  No Data  No Data  No Data  No Data
# freq         83       83       83       83       83       81       81
#
#            2011  2012  2013
# count      3224  3146  3146
# unique      283   291   277
# top     No Data  28.4  25.5
# freq         81    36    39

# %%
df_phy=df_phy.replace('No Data', np.nan)
df_phy=df_phy.astype(float)

# %%
df_phy.describe()
# Out:
#           2004_phy     2005_phy     2006_phy     2007_phy     2008_phy  \
# count  3141.000000  3141.000000  3141.000000  3141.000000  3141.000000
# mean     25.925279    25.904903    26.256224    26.702770    27.058835
# std       5.237766     5.199276     5.388627     5.094992     5.052302
# min       9.200000     9.600000     8.900000     9.800000     9.700000
# 25%      22.600000    22.800000    22.900000    23.700000    24.100000
# 50%      25.800000    25.700000    26.100000    26.800000    27.300000
# 75%      29.100000    28.900000    29.500000    29.900000    30.100000
# max      42.400000    43.900000    44.700000    44.400000    44.800000
#
#           2009_phy     2010_phy     2011_phy     2012_phy     2013_phy
# count  3143.000000  3143.000000  3143.000000  3143.000000  3142.000000
# mean     27.851670    27.843589    26.992809    27.354534    25.951369
# std       5.150904     5.289976     5.321526     5.415192     5.202015
# min      10.100000    10.400000     9.200000     9.100000     8.100000
# 25%      24.550000    24.500000    23.500000    23.900000    22.600000
# 50%      28.200000    28.100000    27.300000    27.600000    25.800000
# 75%      31.300000    31.400000    30.700000    30.900000    29.400000
# max      43.900000    44.900000    42.700000    41.700000    41.400000

# %%
for c in df_phy.columns:
    if c not in ['State', 'County']:       
        df_phy[c].hist(bins=50)
        plt.title('Physical Inactivity prevalence, year '+c)
        plt.figure()
plt.legend()
plt.show()

# %% [markdown]
# Bivariate analysis

# %%
#modify column names for bivariate analysis
df_db.columns=df_db.columns+'_db'
df_ob.columns=df_ob.columns+'_ob'
df_phy.columns=df_phy.columns+'_phy'

df_phy_db_ob=pd.concat([df_phy, df_db, df_db],axis=1)

# %%
print (df_phy_db_ob.head(5))
df_phy_db_ob=df_phy_db_ob.dropna(how='any')
# Out:
#       2004_phy  2005_phy  2006_phy  2007_phy  2008_phy  2009_phy  2010_phy  \
# FIPS
# 1001      31.9      31.0      31.5      33.0      32.7      32.2      29.4
# 1003      26.8      25.8      26.2      24.5      25.2      25.1      27.6
# 1005      34.3      36.1      34.8      34.0      34.9      34.2      35.0
# 1007      28.4      31.5      35.4      36.0      36.6      37.2      37.0
# 1009      29.8      30.3      30.3      32.2      34.6      35.9      35.0
#
#       2011_phy  2012_phy  2013_phy   ...     2004_db  2005_db  2006_db  \
# FIPS                                 ...
# 1001      27.9      28.7      28.6   ...        10.0     11.1     11.4
# 1003      25.2      25.2      22.3   ...         8.1      8.4      9.1
# 1005      32.3      32.9      31.8   ...        10.1     10.7     12.4
# 1007      33.2      33.2      33.9   ...         8.9      9.4     10.9
# 1009      29.8      28.5      28.0   ...         8.3      8.6      9.6
#
#       2007_db  2008_db  2009_db  2010_db  2011_db  2012_db  2013_db
# FIPS
# 1001     11.4     11.4     12.3     11.8     12.1     12.0     13.0
# 1003      9.4      9.8     11.4     11.8     11.5     10.8     10.4
# 1005     13.0     13.6     14.0     14.2     14.8     16.2     18.4
# 1007     11.6     11.1     11.8     11.1     12.7     13.2     14.8
# 1009     10.5     11.4     12.6     14.0     13.2     13.8     14.1
#
# [5 rows x 30 columns]

# %%
for year in range(2007, 2014):
    plt.figure()
    
    df_phy_db_ob.plot(x=str(year)+'_phy', y=str(year)+'_db', kind='scatter')
    plt.xlabel('physical inactivity')
    plt.ylabel('diabetes prevalence')
    plt.title('year '+str(year))
    
    lt.figure()
    df_phy_db_ob.plot(x=str(year)+'_phy', y=str(year)+'_ob', kind='scatter')
    plt.xlabel('physical inactivity')
    plt.ylabel('obesity prevalence')
    plt.title('year '+str(year))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-266-1a47ebe83a65> in <module>()
#       2     plt.figure()
#       3
# ----> 4     df_phy_db_ob.plot(x=str(year)+'_phy', y=str(year)+'_db', kind='scatter')
#       5     plt.xlabel('physical inactivity')
#       6     plt.ylabel('diabetes prevalence')
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1692         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1693
# -> 1694     plot_obj.generate()
#    1695     plot_obj.draw()
#    1696     return plot_obj.result
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     243         self._compute_plot_data()
#     244         self._setup_subplots()
# --> 245         self._make_plot()
#     246         self._add_table()
#     247         self._make_legend()
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in _make_plot(self)
#     842             label = None
#     843         scatter = ax.scatter(data[x].values, data[y].values, c=c_values,
# --> 844                              label=label, cmap=cmap, **self.kwds)
#     845         if cb:
#     846             img = ax.collections[0]
#
# C:\anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# C:\anaconda\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4017         y = np.ma.ravel(y)
#    4018         if x.size != y.size:
# -> 4019             raise ValueError("x and y must be the same size")
#    4020
#    4021         if s is None:
#
# ValueError: x and y must be the same size

# %%
df_access_db_ob=pd.concat([df_access, df_db, df_ob],axis=1)
df_access_db_ob=df_access_db_ob.dropna()

# %%
for c in df_access.columns:
    if c not in ['State','County']:
        df_access_db_ob.plot(x=c,y='2013_db',kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-236-ffe6a7cd62f1> in <module>()
#       1 for c in df_access.columns:
#       2     if c not in ['State','County']:
# ----> 3         df_access_db_ob.plot(x=c,y='2013_db',kind='scatter')
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1650         if isinstance(data, DataFrame):
#    1651             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1652                              kind=kind, **kwds)
#    1653         else:
#    1654             raise ValueError("plot kind %r can only be used for data frames"
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     808             # the handling of this argument later
#     809             s = 20
# --> 810         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     811         if is_integer(c) and not self.data.columns.holds_integer():
#     812             c = self.data.columns[c]
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     785             raise ValueError(self._kind + ' requires x column to be numeric')
#     786         if len(self.data[y]._get_numeric_data()) == 0:
# --> 787             raise ValueError(self._kind + ' requires y column to be numeric')
#     788
#     789         self.x = x
#
# ValueError: scatter requires y column to be numeric

# %%
df_assist_health=pd.concat([df_assist, df_health_subset],axis=1)

# %%
idx_pairs=[(c1,c2) for c1 in df_assist.columns for c2 in df_health_subset.columns]
for p in idx_pairs:
    plt.figure()
    df_assist_health.plot(x=p[0],y=p[1],kind='scatter')
    plt.xlabel(p[0][1])
    plt.ylabel(p[1][1])
plt.show()
# Out:
# C:\anaconda\lib\site-packages\matplotlib\pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
df_rest_health=pd.concat([df_rest, df_health_subset],axis=1)

# %%
idx_pairs=[(c1,c2) for c1 in df_rest.columns for c2 in df_health_subset.columns]
for p in idx_pairs:
    plt.figure()
    df_rest_health.plot(x=p[0],y=p[1],kind='scatter')
    plt.xlabel(p[0][1])
    plt.ylabel(p[1][1])
plt.show()

# %%
df_sto_health=pd.concat([df_sto, df_health_subset],axis=1)

# %%
idx_pairs=[(c1,c2) for c1 in df_sto.columns for c2 in df_health_subset.columns]
for p in idx_pairs:
    plt.figure()
    df_sto_health.plot(x=p[0],y=p[1],kind='scatter',label=df_sto_health[p[0]].corr(df_sto_health[p[1]]))
    plt.xlabel(p[0][1])
    plt.ylabel(p[1][1])
    plt.legend()
plt.show()
# Out:
# C:\anaconda\lib\site-packages\matplotlib\pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
